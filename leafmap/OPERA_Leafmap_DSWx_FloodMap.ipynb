# %% [markdown]
# # Using Leafmap and Earthaccess to Explore OPERA DSWx-HLS Products.
#
# ## Example below showcases a flooding event in the Indus Valley.

# %% [markdown]
# The Leafmap library provides a suite of tools for interactive mapping and visualization in Jupyter Notebooks Leafmap version 0.30.0 and and later offer tools specifically for accessing NASA Earthdata by building on the newly developed NASA Earthaccess library. Earthaccess provides streamlined access to NASA Earthdata and simplifies the authentication and querying process over previously developed approaches.This notebook is designed to leverage tools within Earthaccess and Leafmap to facility easier access and vizualization of OPERA data products for a user-specified area of interest (AOI).

# %% [markdown]
# ## OPERA DSWx-HLS info
# see website https://www.jpl.nasa.gov/go/opera/products/dswx-product-suite

# %% [markdown]
# ## Import Libraries

# %%
import earthaccess
import leafmap
import pandas as pd
import geopandas as gpd
from shapely import box
from datetime import datetime

# %% [markdown]
# ## Authentication
# A [NASA Earthdata Login](https://urs.earthdata.nasa.gov/) account is required to download the data used in this tutorial. You can create an account at the link provided. After establishing an account, the code in the next cell will verify authentication. If this is your first time running the notebook, you will be prompted to enter your Earthdata login credentials, which will be saved in ~/.netrc.

# %%
leafmap.nasa_data_login()

# %% [markdown]
# ## View NASA Earthdata datasets
# A tab separated values (TSV) file, made available through the opengeos Github repository, catalogues metadata for more than 9,000 datasets available through NASA Earthdata. In the next cell we load the TSV into a pandas dataframe and view the metadata for the first five (5) Earthdata products

# %%
### View Earthdata datasets
earthdata_url = 'https://github.com/opengeos/NASA-Earth-Data/raw/main/nasa_earth_data.tsv'
earthdata_df = pd.read_csv(earthdata_url, sep='\t')
# earthdata_df.head()

# %% [markdown]
# ## View the available OPERA products
# Note above that the `earthdata_df` contains a number of columns with metadata about each available product. the `ShortName` column will be used to produce a new dataframe containing only OPERA products. Let's view the available products and their metadata.

# %%
opera_df = earthdata_df[earthdata_df['ShortName'].str.contains('OPERA', case=False)]
# opera_df

# %% [markdown]
# ## Define an area of interest (AOI) and time period of interest (TOI)
# Define an area of interest (AOI) for the flood event

# %%
### This cell initializes the AOI and TOI.

AOI = (67.982054, 26.198739,68.543065, 28.568858) #W, S, E, N; Indus Valley, Pakistan


#Here we have selected two dates. This could expand to include date ranges but then image mosaic rules should be considered (not included here)
StartDate_PreFlood="2023-05-03T00:00:00"  #Pre-flood image start date
EndDate_PreFlood="2023-05-03T23:59:59"    #Pre-flood image end date

StartDate_SynFlood="2023-08-07T00:00:00"  #Syn-flood image start date
EndDate_SynFlood="2023-08-07T23:59:59"    #Syn-flood image end date

# %% [markdown]
# ## Query Earthdata and return metadata for OPERA products within the AOI
# The `earthaccess` library makes it simple to quickly query NASA's Common Metadata Repository (CMR) and return the associated metadata as a Geodataframe. `Leafmap` has recently added functionality that builds on `earthaccess` to enable interactive viewing of this data.
# In the next cell, the user should specify which OPERA product and the date range of interest. The AOI defined previously is used as the boundary in the query.

# %% [markdown]
# ### View OPERA Product Shortnames

# %%
### Print the available OPERA datasets
print('Available OPERA datasets:', opera_df['ShortName'].values)
# Out:
# Available OPERA datasets: ['OPERA_DSWX-HLS_CALVAL_PROVISIONAL_V1' 'OPERA_L2_CSLC-S1-STATIC_V1'
#  'OPERA_L2_CSLC-S1_CALVAL_V1' 'OPERA_L2_CSLC-S1_V1'
#  'OPERA_L2_RTC-S1-STATIC_V1' 'OPERA_L2_RTC-S1_CALVAL_V1'
#  'OPERA_L2_RTC-S1_V1' 'OPERA_L3_DIST-ALERT-HLS_PROVISIONAL_V0'
#  'OPERA_L3_DIST-ALERT-HLS_V1' 'OPERA_L3_DSWX-HLS_PROVISIONAL_V0'
#  'OPERA_L3_DSWX-HLS_PROVISIONAL_V1']

# %% [markdown]
# ### Query the OPERA DSWx-HLS dataset for the AOI

# %%
dswx_results_PreFlood, dswx_gdf_PreFlood = leafmap.nasa_data_search(
    short_name='OPERA_L3_DSWX-HLS_PROVISIONAL_V1',
    cloud_hosted=True,
    bounding_box= AOI,
    temporal=(StartDate_PreFlood, EndDate_PreFlood),
    count=-1,  # use -1 to return all datasets
    return_gdf=True,
)

dswx_results_SynFlood, dswx_gdf_SynFlood = leafmap.nasa_data_search(
    short_name='OPERA_L3_DSWX-HLS_PROVISIONAL_V1',
    cloud_hosted=True,
    bounding_box= AOI,
    temporal=(StartDate_SynFlood, EndDate_SynFlood),
    count=-1,  # use -1 to return all datasets
    return_gdf=True,
)
# Out:
# Granules found: 16
# Granules found: 8

# %% [markdown]
# ### See the available DSWx-HLS layers
# Functionality within earthaccess enables more more asthetic views of the available layers, as well as displaying the thumbnail. These links are clickable and will download in the browser when clicked.

# %%
dswx_results_PreFlood[0] #Note this just shows a single MGRS/HLS tile
# Out:
# Collection: {'Version': '1.0', 'ShortName': 'OPERA_L3_DSWX-HLS_PROVISIONAL_V1'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': 66.947, 'SouthBoundingCoordinate': 28.01, 'EastBoundingCoordinate': 68.082, 'NorthBoundingCoordinate': 29.013}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2023-05-03T05:55:23.100Z', 'BeginningDateTime': '2023-05-03T05:55:23.100Z'}}
# Size(MB): 37.72839069366455
# Data: ['https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B01_WTR.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B02_BWTR.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B03_CONF.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B04_DIAG.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B05_WTR-1.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B06_WTR-2.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B07_LAND.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B08_SHAD.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B09_CLOUD.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B10_DEM.tif']

# %%
dswx_results_SynFlood[0] #Note this just shows a single MGRS/HLS tile
# Out:
# Collection: {'Version': '1.0', 'ShortName': 'OPERA_L3_DSWX-HLS_PROVISIONAL_V1'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'BoundingRectangles': [{'WestBoundingCoordinate': 66.947, 'SouthBoundingCoordinate': 28.01, 'EastBoundingCoordinate': 68.082, 'NorthBoundingCoordinate': 29.013}]}}}
# Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2023-08-07T05:55:47.555Z', 'BeginningDateTime': '2023-08-07T05:55:47.555Z'}}
# Size(MB): 39.963419914245605
# Data: ['https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B01_WTR.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B02_BWTR.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B03_CONF.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B04_DIAG.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B05_WTR-1.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B06_WTR-2.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B07_LAND.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B08_SHAD.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B09_CLOUD.tif', 'https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/OPERA_L3_DSWX-HLS_PROVISIONAL_V1/OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B10_DEM.tif']

# %% [markdown]
# ### View the DSWx-HLS metadata and footprints

# %%
dswx_gdf_PreFlood.head()
# Out:
#         size concept-type           concept-id  revision-id  \
# 0  37.728391      granule  G2678027683-POCLOUD            2
# 1  37.843202      granule  G2678027771-POCLOUD            2
# 2  41.075684      granule  G2678027702-POCLOUD            2
# 3  40.671881      granule  G2678027706-POCLOUD            2
# 4  43.698020      granule  G2678027721-POCLOUD            2
#
#                                            native-id collection-concept-id  \
# 0  OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_2023...   C2617126679-POCLOUD
# 1  OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_2023...   C2617126679-POCLOUD
# 2  OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_2023...   C2617126679-POCLOUD
# 3  OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_2023...   C2617126679-POCLOUD
# 4  OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_2023...   C2617126679-POCLOUD
#
#   provider-id                             format             revision-date  \
# 0     POCLOUD  application/vnd.nasa.cmr.umm+json  2024-01-03T00:33:02.185Z
# 1     POCLOUD  application/vnd.nasa.cmr.umm+json  2024-01-03T00:33:02.337Z
# 2     POCLOUD  application/vnd.nasa.cmr.umm+json  2024-01-03T00:33:02.446Z
# 3     POCLOUD  application/vnd.nasa.cmr.umm+json  2024-01-03T00:33:02.815Z
# 4     POCLOUD  application/vnd.nasa.cmr.umm+json  2024-01-03T00:33:02.693Z
#
#              EndingDateTime  ... CloudCover  \
# 0  2023-05-03T05:55:23.100Z  ...          0
# 1  2023-05-03T05:55:23.100Z  ...          0
# 2  2023-05-03T05:55:46.991Z  ...          0
# 3  2023-05-03T05:55:46.991Z  ...          0
# 4  2023-05-03T05:55:46.991Z  ...          1
#
#                                        InputGranules  \
# 0  [/home/conda/input_dir/GSHHS_f_L1.dbf, /home/c...
# 1  [/home/conda/input_dir/GSHHS_f_L1.dbf, /home/c...
# 2  [/home/conda/input_dir/GSHHS_f_L1.dbf, /home/c...
# 3  [/home/conda/input_dir/GSHHS_f_L1.dbf, /home/c...
# 4  [/home/conda/input_dir/GSHHS_f_L1.dbf, /home/c...
#
#                    ArchiveAndDistributionInformation DayNightFlag  \
# 0  [{'SizeUnit': 'MB', 'Size': 3.0517578125e-05, ...  Unspecified
# 1  [{'SizeUnit': 'MB', 'Size': 3.0517578125e-05, ...  Unspecified
# 2  [{'SizeUnit': 'MB', 'Size': 38.88541603088379,...  Unspecified
# 3  [{'SizeUnit': 'MB', 'Size': 0.1550302505493164...  Unspecified
# 4  [{'SizeUnit': 'MB', 'Size': 0.7969980239868164...  Unspecified
#
#                                          Identifiers  \
# 0  [{'Identifier': 'OPERA_L3_DSWx-HLS_T42RUS_2023...
# 1  [{'Identifier': 'OPERA_L3_DSWx-HLS_T42RVS_2023...
# 2  [{'Identifier': 'OPERA_L3_DSWx-HLS_T42RUR_2023...
# 3  [{'Identifier': 'OPERA_L3_DSWx-HLS_T42RUQ_2023...
# 4  [{'Identifier': 'OPERA_L3_DSWx-HLS_T42RVR_2023...
#
#          ProductionDateTime  \
# 0  2023-05-05T09:32:10.119Z
# 1  2023-05-05T09:32:12.612Z
# 2  2023-05-05T09:31:44.764Z
# 3  2023-05-05T09:31:45.344Z
# 4  2023-05-05T09:31:56.240Z
#
#                                                  URL   Name  \
# 0  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5  UMM-G
# 1  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5  UMM-G
# 2  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5  UMM-G
# 3  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5  UMM-G
# 4  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.5  UMM-G
#
#                                bbox  \
# 0   (66.947, 28.01, 68.082, 29.013)
# 1  (67.973, 28.021, 69.101, 29.016)
# 2   (66.964, 27.108, 68.09, 28.111)
# 3  (66.981, 26.206, 68.097, 27.208)
# 4    (67.982, 27.119, 69.1, 28.114)
#
#                                             geometry
# 0  POLYGON ((68.08200 28.01000, 68.08200 29.01300...
# 1  POLYGON ((69.10100 28.02100, 69.10100 29.01600...
# 2  POLYGON ((68.09000 27.10800, 68.09000 28.11100...
# 3  POLYGON ((68.09700 26.20600, 68.09700 27.20800...
# 4  POLYGON ((69.10000 27.11900, 69.10000 28.11400...
#
# [5 rows x 29 columns]

# %%
### Plot the location of the tiles 
dswx_gdf_PreFlood.explore(fill=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e18035daa6f729b19dedde9d312a06ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e18035daa6f729b19dedde9d312a06ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e18035daa6f729b19dedde9d312a06ff = L.map(
#                 &quot;map_e18035daa6f729b19dedde9d312a06ff&quot;,
#                 {
#                     center: [27.1595, 68.024],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e18035daa6f729b19dedde9d312a06ff);
#
#
#
#
#
#             var tile_layer_42217c34a5a9471620407a774758b6dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_42217c34a5a9471620407a774758b6dc.addTo(map_e18035daa6f729b19dedde9d312a06ff);
#
#
#             map_e18035daa6f729b19dedde9d312a06ff.fitBounds(
#                 [[25.303, 66.947], [29.016, 69.101]],
#                 {}
#             );
#
#
#         function geo_json_479fd9ed198b3871f15c6b0bad6c2138_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_479fd9ed198b3871f15c6b0bad6c2138_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_479fd9ed198b3871f15c6b0bad6c2138_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_479fd9ed198b3871f15c6b0bad6c2138_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_479fd9ed198b3871f15c6b0bad6c2138_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_479fd9ed198b3871f15c6b0bad6c2138.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_479fd9ed198b3871f15c6b0bad6c2138_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_479fd9ed198b3871f15c6b0bad6c2138 = L.geoJson(null, {
#                 onEachFeature: geo_json_479fd9ed198b3871f15c6b0bad6c2138_onEachFeature,
#
#                 style: geo_json_479fd9ed198b3871f15c6b0bad6c2138_styler,
#                 pointToLayer: geo_json_479fd9ed198b3871f15c6b0bad6c2138_pointToLayer,
#                 fill: false,
#         });
#
#         function geo_json_479fd9ed198b3871f15c6b0bad6c2138_add (data) {
#             geo_json_479fd9ed198b3871f15c6b0bad6c2138
#                 .addData(data);
#         }
#             geo_json_479fd9ed198b3871f15c6b0bad6c2138_add({&quot;bbox&quot;: [66.947, 25.303, 69.101, 29.016], &quot;features&quot;: [{&quot;bbox&quot;: [66.947, 28.01, 68.082, 29.013], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[68.082, 28.01], [68.082, 29.013], [66.947, 29.013], [66.947, 28.01], [68.082, 28.01]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AdditionalAttributes&quot;: [{&quot;Name&quot;: &quot;HlsDataset&quot;, &quot;Values&quot;: [&quot;HLS.L30.T42RUS.2023123T055523.v2.0&quot;]}, {&quot;Name&quot;: &quot;Sensor&quot;, &quot;Values&quot;: [&quot;OLI&quot;]}, {&quot;Name&quot;: &quot;SensorProductID&quot;, &quot;Values&quot;: [&quot;LC08_L1TP_152040_20230503_20230503_02_RT; LC08_L1TP_152041_20230503_20230503_02_RT&quot;]}, {&quot;Name&quot;: &quot;Accode&quot;, &quot;

# %%
### Plot the location of the tiles 
dswx_gdf_SynFlood.explore(fill=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5346fe07862eddf34fb0575519ebbd2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5346fe07862eddf34fb0575519ebbd2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5346fe07862eddf34fb0575519ebbd2b = L.map(
#                 &quot;map_5346fe07862eddf34fb0575519ebbd2b&quot;,
#                 {
#                     center: [27.1595, 68.024],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5346fe07862eddf34fb0575519ebbd2b);
#
#
#
#
#
#             var tile_layer_ebcdb29f3cb6ff584e2e084f520903ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ebcdb29f3cb6ff584e2e084f520903ab.addTo(map_5346fe07862eddf34fb0575519ebbd2b);
#
#
#             map_5346fe07862eddf34fb0575519ebbd2b.fitBounds(
#                 [[25.303, 66.947], [29.016, 69.101]],
#                 {}
#             );
#
#
#         function geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_92fa2cbfe61c822d0c9d0a421407d9bb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_92fa2cbfe61c822d0c9d0a421407d9bb = L.geoJson(null, {
#                 onEachFeature: geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_onEachFeature,
#
#                 style: geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_styler,
#                 pointToLayer: geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_pointToLayer,
#                 fill: false,
#         });
#
#         function geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_add (data) {
#             geo_json_92fa2cbfe61c822d0c9d0a421407d9bb
#                 .addData(data);
#         }
#             geo_json_92fa2cbfe61c822d0c9d0a421407d9bb_add({&quot;bbox&quot;: [66.947, 25.303, 69.101, 29.016], &quot;features&quot;: [{&quot;bbox&quot;: [66.947, 28.01, 68.082, 29.013], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[68.082, 28.01], [68.082, 29.013], [66.947, 29.013], [66.947, 28.01], [68.082, 28.01]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AdditionalAttributes&quot;: [{&quot;Name&quot;: &quot;HlsDataset&quot;, &quot;Values&quot;: [&quot;HLS.L30.T42RUS.2023219T055547.v2.0&quot;]}, {&quot;Name&quot;: &quot;Sensor&quot;, &quot;Values&quot;: [&quot;OLI&quot;]}, {&quot;Name&quot;: &quot;SensorProductID&quot;, &quot;Values&quot;: [&quot;LC08_L1TP_152040_20230807_20230807_02_RT; LC08_L1TP_152041_20230807_20230807_02_RT&quot;]}, {&quot;Name&quot;: &quot;Accode&quot;, &quot;

# %% [markdown]
# ## Download data with leafmap
# Let's download the data from one of our above queries. In the cell below we specify data from the DSWx-HLS.

# %% [markdown]
# ### Create a subdirectory
# This will be where the files are downloaded. It will be a subdirectory inside of a directory called `data`, and the directory name will be the date that it was created.

# %%
import os
from datetime import datetime

def create_data_directory():
    # Get the current date and time
    # current_datetime = datetime.now().strftime("%m_%d_%Y_%H_%M_%S")
    current_datetime = datetime.now().strftime("%m_%d_%Y")

    # Define the base directory
    base_directory = "data"

    # Create the full path for the new directory
    new_directory_path_PreFlood = os.path.join(base_directory, f"data_{current_datetime}/PreFlood")
    # Create the new directory
    os.makedirs(new_directory_path_PreFlood, exist_ok=True)

    print(f"Directory '{new_directory_path_PreFlood}' created successfully.")

    return new_directory_path_PreFlood 

directory_path_PreFlood = create_data_directory()
# Out:
# Directory 'data/data_04_04_2024/PreFlood' created successfully.

# %%
def create_data_directory():
    # Get the current date and time
    # current_datetime = datetime.now().strftime("%m_%d_%Y_%H_%M_%S")
    current_datetime = datetime.now().strftime("%m_%d_%Y")

    # Define the base directory
    base_directory = "data"

    # Create the full path for the new directory
    new_directory_path_SynFlood = os.path.join(base_directory, f"data_{current_datetime}/SynFlood")
    # Create the new directory
    os.makedirs(new_directory_path_SynFlood, exist_ok=True)

    print(f"Directory '{new_directory_path_SynFlood}' created successfully.")

    return new_directory_path_SynFlood 

directory_path_SynFlood = create_data_directory()
# Out:
# Directory 'data/data_04_04_2024/SynFlood' created successfully.

# %% [markdown]
# ### Download the data
# The below will download the data to your newly created subdirectory. Look on your file system for a directory `/data/date/` where `date` is the date the directory was created.

# %%
dswx_data_PreFlood = leafmap.nasa_data_download(dswx_results_PreFlood, out_dir=directory_path_PreFlood)
# Out:
#  Getting 16 granules, approx download size: 0.64 GB
# QUEUEING TASKS | :   0%|          | 0/160 [00:00<?, ?it/s]
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B01_WTR.tif already downloadedFile OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B02_BWTR.tif already downloaded
#
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055523Z_20230505T093210Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055523Z_20230505T093213Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055546Z_20230505T093145Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055546Z_20230505T093309Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055610Z_20230505T093113Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055610Z_20230505T093052Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230503T055639Z_20230505T174220Z_S2B_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230503T055639Z_20230505T174200Z_S2B_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055639Z_20230505T122326Z_S2B_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230503T055639Z_20230505T203348Z_S2B_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230503T055639Z_20230505T174211Z_S2B_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230503T055639Z_20230505T174204Z_S2B_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230503T055639Z_20230505T174203Z_S2B_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230503T055546Z_20230505T093156Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230503T055639Z_20230505T174202Z_S2B_30_v1.0_B06_WTR-2.tif already downloaded
# PROCESSING TASKS | :   0%|          | 0/160 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/160 [00:00<?, ?it/s]

# %%
dswx_data_SynFlood = leafmap.nasa_data_download(dswx_results_SynFlood, out_dir=directory_path_SynFlood)
# Out:
#  Getting 8 granules, approx download size: 0.33 GB
# QUEUEING TASKS | :   0%|          | 0/80 [00:00<?, ?it/s]
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B02_BWTR.tif already downloadedFile OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B01_WTR.tif already downloaded
#
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUS_20230807T055547Z_20230810T171908Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVS_20230807T055547Z_20230810T171906Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVR_20230807T055611Z_20230810T171908Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUR_20230807T055611Z_20230810T171907Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUQ_20230807T055611Z_20230810T192335Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B04_DIAG.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B03_CONF.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B07_LAND.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B08_SHAD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B09_CLOUD.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B05_WTR-1.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVQ_20230807T055611Z_20230810T192336Z_L8_30_v1.0_B10_DEM.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B06_WTR-2.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RUP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B01_WTR.tif already downloaded
# File OPERA_L3_DSWx-HLS_T42RVP_20230807T055635Z_20230810T192342Z_L8_30_v1.0_B02_BWTR.tif already downloaded
# PROCESSING TASKS | :   0%|          | 0/80 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/80 [00:00<?, ?it/s]

# %% [markdown]
# ## View the files using Leafmap

# %% [markdown]
# ### Load in images from data folder
# We load in data from only the DSWx-WTR layer below. If you'd like load data from a different layer change the `B01` to suit your needs.
# Included layers:
#
#
# OPERA_L3_DSWx-HLS_*B01_WTR.tif
#
#
# OPERA_L3_DSWx-HLS_*B02_BWTR.tif
#
#
# OPERA_L3_DSWx-HLS_*B03_CONF.tif
#
#
# OPERA_L3_DSWx-HLS_*B04_DIAG.tif
#
#
# OPERA_L3_DSWx-HLS_*B05_WTR-1.tif
#
#
# OPERA_L3_DSWx-HLS_*B06_WTR-2.tif
#
#
# OPERA_L3_DSWx-HLS_*B07_LAND.tif
#
#
# OPERA_L3_DSWx-HLS_*B08_SHAD.tif
#
#
# OPERA_L3_DSWx-HLS_*B09_CLOUD.tif
#
#
# OPERA_L3_DSWx-HLS_*B10_DEM.tif

# %%
import os

ImageLayer='B01' #B01 corresponds to WTR (see above)

# Get the current directory
current_directory = os.getcwd()

# Construct the path to the data directory
data_directory_PreFlood = os.path.join(current_directory, directory_path_PreFlood)
data_directory_SynFlood = os.path.join(current_directory, directory_path_SynFlood)

# Create a list of file paths and a list of corresponding dates
images_PreFlood = [os.path.join(data_directory_PreFlood, filename) for filename in os.listdir(data_directory_PreFlood) if os.path.isfile(os.path.join(data_directory_PreFlood, filename)) and ImageLayer in filename]
image_dates_PreFlood = [image[25:33] for image in os.listdir(data_directory_PreFlood) if ImageLayer in image]

images_SynFlood = [os.path.join(data_directory_SynFlood, filename) for filename in os.listdir(data_directory_SynFlood) if os.path.isfile(os.path.join(data_directory_SynFlood, filename)) and ImageLayer in filename]
image_dates_SynFlood = [image[25:33] for image in os.listdir(data_directory_SynFlood) if ImageLayer in image]

# %% [markdown]
# ### Merge individual tiles into a single image

# %%
filename_merged_PreFlood='PreFlood_Merged.tif'
merged_raster_PreFlood = leafmap.merge_rasters(data_directory_PreFlood,os.path.join(data_directory_PreFlood, filename_merged_PreFlood),input_pattern='*' + ImageLayer +'*.tif',output_format='GTiff',output_nodata=None)

# %%
filename_merged_SynFlood='SynFlood_Merged.tif'
merged_raster_SynFlood = leafmap.merge_rasters(data_directory_SynFlood,os.path.join(data_directory_SynFlood, filename_merged_SynFlood),input_pattern= '*' + ImageLayer +'*.tif',output_format='GTiff',output_nodata=None)

# %% [markdown]
# ### Display the merged images

# %%
m = leafmap.Map(basemap="Esri.WorldImagery")
# m.add_raster(os.path.join(data_directory_PreFlood, filename_merged_PreFlood), opacity=1)
m.add_raster(os.path.join(data_directory_SynFlood, filename_merged_SynFlood), opacity=1)
legend_dict = {
    'Not Water': '##ffffff',
    'Open Surface Water': '#0000ff',
    'Partial Surface Water': '#b4d5f4',
    'HLS snow/ice mask': '#00ffff',
    'HLS cloud/cloud shadow mask': '#afafaf'
}
# Add the legend to the map
m.add_legend(legend_title="Legend Title", legend_dict=legend_dict)

m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ## Create a split map to show changes

# %%
raster_PreFlood_path=os.path.join(data_directory_PreFlood, filename_merged_PreFlood)
raster_SynFlood_path=os.path.join(data_directory_SynFlood, filename_merged_SynFlood)

# %%
raster_path_2merged=[raster_PreFlood_path,raster_SynFlood_path]
#for only 2 dates - will need to update if more dates are used in merge
image_dates_merged=[image_dates_PreFlood[0],image_dates_SynFlood[0]]

# %%
leafmap.split_map(
    left_layer=raster_PreFlood_path,
    right_layer=raster_SynFlood_path,
    # opacity=0.5,
    left_label="First",
    right_label="Last",
    label_position="bottom",
    basemap="Esri.WorldImagery",
    zoom=10,
)

#have not yet figured out how to get legend on the split map
# legend_dict = {
#     'Not Water': '##ffffff',
#     'Open Surface Water': '#0000ff',
#     'Partial Surface Water': '#b4d5f4',
#     'HLS snow/ice mask': '#00ffff',
#     'HLS cloud/cloud shadow mask': '#afafaf'
# }
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ## Reclassify values
# We have found that sometimes sediment rich water is classified as snow/ice in the HLS FMask. If the user is certain there is no snow/ice in the imagery, this layer can be reclassified.

# %%
#Not yet set up

# %% [markdown]
# ### Conclusions
# This is a first `earthaccess` and `leafmap` notebook for flood application. More work is needed to expand features for sophisticated filtering (cloud cover, spatial overlap) and analysis.
