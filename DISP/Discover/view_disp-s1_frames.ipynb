# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# # Select background tiles

# %%
# To use satellite imagery, the `xyzserives` must be installed
try:
    import xyzservices

    tiles = xyzservices.providers["Esri"]["WorldImagery"]
except:
    # Use default
    tiles = None

# %% [markdown]
# # Loading data

# %%
df_selected_bursts = pd.read_csv(
    "selected_bursts_option0.csv.zip", parse_dates=["sensing_date"]
)
df_selected_bursts.sensing_date = df_selected_bursts.sensing_date.dt.date


df_selected_bursts.head(3)
# Out:
#    frame_id  total_num_bursts     burst_id_jpl sensing_date  \
# 0       831              5022  t004_006641_iw1   2017-02-15
# 1       831              5022  t004_006641_iw1   2017-02-27
# 2       831              5022  t004_006641_iw1   2017-03-11
#
#    num_candidate_bursts
# 0                  5298
# 1                  5298
# 2                  5298

# %%
df_selected_bursts_grouped = (
    df_selected_bursts[["burst_id_jpl", "frame_id"]]
    .groupby(("burst_id_jpl"))
    .count()
    .rename({"frame_id": "date_count"}, axis=1)
)

df_selected_bursts_grouped.head()
# Out:
#                  date_count
# burst_id_jpl
# t004_006641_iw1         186
# t004_006641_iw2         186
# t004_006641_iw3         186
# t004_006642_iw1         186
# t004_006642_iw2         186

# %%
df_burst_geoms = gpd.read_file("na_bursts_with_geom.geojson.zip")
df_burst_geoms.head(3)
# Out:
#    frame_id     burst_id_jpl orbit_pass  \
# 0      1653  t007_013218_iw1  ASCENDING
# 1      1653  t007_013222_iw3  ASCENDING
# 2      1653  t007_013225_iw2  ASCENDING
#
#                                             geometry
# 0  MULTIPOLYGON (((-157.82827 55.48763, -157.1283...
# 1  MULTIPOLYGON (((-155.37657 56.54824, -154.7210...
# 2  MULTIPOLYGON (((-156.93933 56.84940, -156.1855...

# %%
df_burst_count = pd.merge(df_selected_bursts_grouped, df_burst_geoms, on="burst_id_jpl")
df_burst_count = gpd.GeoDataFrame(df_burst_count, geometry="geometry")
df_burst_count.head()
# Out:
#       burst_id_jpl  date_count  frame_id orbit_pass  \
# 0  t004_006641_iw1         186       831  ASCENDING
# 1  t004_006641_iw2         186       831  ASCENDING
# 2  t004_006641_iw3         186       831  ASCENDING
# 3  t004_006642_iw1         186       831  ASCENDING
# 4  t004_006642_iw2         186       831  ASCENDING
#
#                                             geometry
# 0  MULTIPOLYGON (((-77.59315 33.46137, -77.11728 ...
# 1  MULTIPOLYGON (((-76.71825 33.66354, -76.22176 ...
# 2  MULTIPOLYGON (((-75.79204 33.85517, -75.35592 ...
# 3  MULTIPOLYGON (((-77.63169 33.62745, -77.15485 ...
# 4  MULTIPOLYGON (((-76.75500 33.82960, -76.25752 ...

# %%
# Aggregate burst-wise polygons
frame_based = df_burst_count.dissolve(by='frame_id').reset_index()
frame_based["path_number"] = frame_based.burst_id_jpl.str[1:4].astype(int)
frame_based = frame_based.drop(columns='burst_id_jpl')
frame_based
# Out:
#       frame_id                                           geometry  date_count  \
# 0          831  POLYGON ((-77.63462 33.64007, -77.67350 33.807...         186
# 1          832  POLYGON ((-77.94234 34.97052, -77.98167 35.136...         387
# 2          833  POLYGON ((-78.25450 36.29876, -78.29421 36.463...         402
# 3          834  POLYGON ((-78.57216 37.62689, -78.61245 37.791...         399
# 4          835  POLYGON ((-78.89565 38.95445, -78.93684 39.119...         394
# ...        ...                                                ...         ...
# 1428     46541  POLYGON ((-134.76723 56.39017, -135.42777 56.4...         284
# 1429     46542  POLYGON ((-135.18571 55.07265, -135.82487 55.1...         271
# 1430     46543  POLYGON ((-135.58757 53.75420, -136.20699 53.8...         264
# 1431     46799  MULTIPOLYGON (((-151.98765 70.03128, -153.1816...           2
# 1432     46800  POLYGON ((-149.95093 69.73885, -150.09686 69.5...           1
#
#       orbit_pass  path_number
# 0      ASCENDING            4
# 1      ASCENDING            4
# 2      ASCENDING            4
# 3      ASCENDING            4
# 4      ASCENDING            4
# ...          ...          ...
# 1428  DESCENDING          174
# 1429  DESCENDING          174
# 1430  DESCENDING          174
# 1431  DESCENDING          175
# 1432  DESCENDING          175
#
# [1433 rows x 5 columns]

# %% [markdown]
# # View Ascending Frames

# %%
frame_based[frame_based.orbit_pass == "ASCENDING"].explore(tiles=tiles, color='red')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91e88b43b65760f8c5c89dcaf57f6e8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91e88b43b65760f8c5c89dcaf57f6e8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91e88b43b65760f8c5c89dcaf57f6e8a = L.map(
#                 &quot;map_91e88b43b65760f8c5c89dcaf57f6e8a&quot;,
#                 {
#                     center: [28.711052000000002, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_91e88b43b65760f8c5c89dcaf57f6e8a);
#
#
#
#
#
#             var tile_layer_ffc86c683ebda11b15de1354c756d46c = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ffc86c683ebda11b15de1354c756d46c.addTo(map_91e88b43b65760f8c5c89dcaf57f6e8a);
#
#
#             map_91e88b43b65760f8c5c89dcaf57f6e8a.fitBounds(
#                 [[-14.957742, -180.0], [72.379846, 180.0]],
#                 {}
#             );
#
#
#         function geo_json_616563e858d82937c123060f632536ca_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_616563e858d82937c123060f632536ca_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_616563e858d82937c123060f632536ca_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_616563e858d82937c123060f632536ca_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_616563e858d82937c123060f632536ca_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_616563e858d82937c123060f632536ca.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_616563e858d82937c123060f632536ca_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_616563e858d82937c123060f632536ca = L.geoJson(null, {
#                 onEachFeature: geo_json_616563e858d82937c123060f632536ca_onEachFeature,
#
#                 style: geo_json_616563e858d82937c123060f632536ca_styler,
#                 pointToLayer: geo_json_616563e858d82937c123060f632536ca_pointToLayer,
#         });
#
#         function geo_json_616563e858d82937c123060f632536ca_add (data) {
#             geo_json_616563e858d82937c123060f632536ca
#                 .addData(data);
#         }
#             geo_json_616563e858d82937c123060f632536ca_add({&quot;bbox&quot;: [-180.0, -14.957742, 180.0, 72.379846], &quot;features&quot;: [{&quot;bbox&quot;: [-77.945762, 33.461372, -74.935896, 35.502944], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-77.6346222979726, 33.64007470830706], [-77.67350124725361, 33.80726646895343], [-77.715666, 33.98823], [-77.71201722628514, 33.98882268467425], [-77.74739413831402, 34.14038365202853], [-77.78614016813421, 34.30604817572632], [-77.82534264540496, 34.47332490742106], [-77.86423859108328, 34.63895378969507], [-77.90313824056294, 34.804263503373164], [-77.945762, 34.985022], [-77.462237, 35.062549], [-77.04163562340203, 35.12841170748985], [-77.05238, 35.1763], [-76.547

# %% [markdown]
# # View Descending Frames

# %%
frame_based[frame_based.orbit_pass == "DESCENDING"].explore(tiles=tiles)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_633fdeaf9589ec02998b6ba4ef006892 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_633fdeaf9589ec02998b6ba4ef006892&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_633fdeaf9589ec02998b6ba4ef006892 = L.map(
#                 &quot;map_633fdeaf9589ec02998b6ba4ef006892&quot;,
#                 {
#                     center: [38.9020205, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_633fdeaf9589ec02998b6ba4ef006892);
#
#
#
#
#
#             var tile_layer_a666c010999c56e44eb72ea95b65dfb5 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a666c010999c56e44eb72ea95b65dfb5.addTo(map_633fdeaf9589ec02998b6ba4ef006892);
#
#
#             map_633fdeaf9589ec02998b6ba4ef006892.fitBounds(
#                 [[6.015095, -180.0], [71.788946, 180.0]],
#                 {}
#             );
#
#
#         function geo_json_533e6ab1ea8260a7af186a7293450ea7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_533e6ab1ea8260a7af186a7293450ea7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_533e6ab1ea8260a7af186a7293450ea7_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_533e6ab1ea8260a7af186a7293450ea7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_533e6ab1ea8260a7af186a7293450ea7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_533e6ab1ea8260a7af186a7293450ea7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_533e6ab1ea8260a7af186a7293450ea7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_533e6ab1ea8260a7af186a7293450ea7 = L.geoJson(null, {
#                 onEachFeature: geo_json_533e6ab1ea8260a7af186a7293450ea7_onEachFeature,
#
#                 style: geo_json_533e6ab1ea8260a7af186a7293450ea7_styler,
#                 pointToLayer: geo_json_533e6ab1ea8260a7af186a7293450ea7_pointToLayer,
#         });
#
#         function geo_json_533e6ab1ea8260a7af186a7293450ea7_add (data) {
#             geo_json_533e6ab1ea8260a7af186a7293450ea7
#                 .addData(data);
#         }
#             geo_json_533e6ab1ea8260a7af186a7293450ea7_add({&quot;bbox&quot;: [-180.0, 6.015095, 180.0, 71.788946], &quot;features&quot;: [{&quot;bbox&quot;: [-75.242402, 46.946807, -71.881714, 47.42115], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-73.005106, 47.290173], [-72.464049, 47.219776], [-71.881714, 47.141123], [-71.938392, 46.946807], [-72.51979, 47.020884], [-73.0251371817257, 47.08247830086877], [-73.037959, 47.035001], [-73.644119, 47.106369], [-74.18334001087365, 47.16681228960666], [-74.198049, 47.107411], [-74.729904, 47.164195], [-75.242402, 47.216381], [-75.195814, 47.42115], [-74.682391, 47.364354], [-74.18362475985408, 47.30687008658755], [-74.169781, 47.362867], [-73.595547, 47.294408], [-73.02318096318074, 47.22315798151743], [-73.005106, 47.290173]]], &quot;type&quot;: &quot;
