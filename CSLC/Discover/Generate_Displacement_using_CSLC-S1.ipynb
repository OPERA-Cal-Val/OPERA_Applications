# %% [markdown]
# # Generate displacement data using OPERA CSLC-S1 from ASF DAAC
#
# ---
#
# ### Data Used in the Example:
#
# - **10 meter (Northing) x 5 meter (Easting) North America OPERA Coregistered Single Look Complex from Sentinel-1 products**
#     - This dataset contains Level-2 OPERA coregistered single-look-complex (CSLC) data from Sentinel-1 (S1). <span style="color:red"> The data in this example are geocoded CSLC-S1 data covering the volcanoes in the Big Island, Hawaii</span>.
#
#     - The OPERA project is generating geocoded burst-wise CSLC-S1 products over North America which includes USA and US Territories within 200 km from the US border, Canada, and all mainland countries from the southern US border down to and including Panama. Each pixel within a burst SLC is represented by a complex number and contains both the amplitude and phase information. The CSLC-S1 products are distributed over projected map coordinates using the Universal Transverse Mercator (UTM) projection with spacing in the X- and Y-directions of 5 m and 10 m, respectively. Each OPERA CSLC-S1 product is distributed as a HDF5 file following the CF-1.8 convention with separate groups containing the data raster layers, the low-resolution correction layers, and relevant product metadata.
#
#     - For more information about the OPERA project and other products please visit our website at https://www.jpl.nasa.gov/go/opera .
#
# Please refer to the [OPERA Product Specification Document](https://d2pn8kiwq2w21t.cloudfront.net/documents/ProductSpec_CSLC_URS314199.pdf) for details about the CSLC-S1 product.
#
# *Prepared by M. Grace Bato*
#
# ---

# %% [markdown]
# ## 0. Setup your conda environment
#
# Assuming you have [miniconda](https://docs.conda.io/projects/miniconda/en/latest/miniconda-install.html) or conda installed. Open your terminal and run the following:
# ```
# > conda create -n opera_cslc --yes
# > conda activate opera_cslc
# > conda install -c conda-forge mamba --yes
# > mamba env update -p ${CONDA_PREFIX} --file "opera_cslc_env.yml"
# > pip install -U git+https://github.com/scottstanie/dolphin.git@main
# ```
#
# ---

# %% [markdown]
# ## 1. Load Python modules

# %%
## Load necessary modules
# %load_ext watermark

import asf_search as asf
import geopandas as gpd

import numpy as np
import getpass
import folium
import datetime as dt
from shapely.geometry import box
import rioxarray
import numpy as np
from dolphin.workflows import _cli_config as dconfig
from dolphin.workflows import _cli_run as drun

# %watermark --iversions

import os
# Out:
# numpy     : 1.26.2
# dolphin   : 0.7.0.post1.dev23+gbd31392
# geopandas : 0.14.1
# folium    : 0.15.1
# asf_search: 6.7.2
# rioxarray : 0.15.0

# %%
## Load plotting module
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
## Load pandas and setup config
import pandas as pd
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
## Avoid lots of these warnings printing to notebook from asf_search
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Query and download OPERA CSLCs using `asf_search`

# %%
## Enter user-defined parameters
aoi = box(-155.88, 19.0, -155.014, 20.1962)     # (W, S, E, N)
wavelength = 0.056
orbitPass = asf.ASCENDING
pathNumber = 124
referenceDate = dt.datetime.fromisoformat('2023-12-14 00:00:00')         #'YYYY-MM-DD HH:MM:SS'
secondaryDate = dt.datetime.fromisoformat('2023-12-26 23:59:59')         #'YYYY-MM-DD HH:MM:SS'
savedir = './BigIsland'

# %%
## Search for OPERA CSLC data in ASF DAAC
search_params = dict(
    intersectsWith= aoi.wkt,
    dataset='OPERA-S1',
    processingLevel='CSLC',
    flightDirection = orbitPass,
    start=referenceDate,
    end=secondaryDate
)

## Return results
results = asf.search(**search_params)
len(results)
# Out:
# 67

# %%
## Display the queried data
gf = gpd.GeoDataFrame.from_features(results.geojson(), crs='EPSG:4326')
gf.head()
# Out:
#                                             geometry beamModeType  \
# 0  POLYGON ((-156.15680 20.12214, -155.30759 20.2...           IW
# 1  POLYGON ((-155.30681 20.16151, -154.55619 20.2...           IW
# 2  POLYGON ((-156.12276 19.95542, -155.27450 20.1...           IW
# 3  POLYGON ((-155.27364 19.99466, -154.52386 20.1...           IW
# 4  POLYGON ((-156.08868 19.78844, -155.24136 19.9...           IW
#
#                                               browse bytes centerLat  \
# 0  [https://datapool.asf.alaska.edu/BROWSE/OPERA-...  None      None
# 1  [https://datapool.asf.alaska.edu/BROWSE/OPERA-...  None      None
# 2  [https://datapool.asf.alaska.edu/BROWSE/OPERA-...  None      None
# 3  [https://datapool.asf.alaska.edu/BROWSE/OPERA-...  None      None
# 4  [https://datapool.asf.alaska.edu/BROWSE/OPERA-...  None      None
#
#   centerLon faradayRotation  \
# 0      None            None
# 1      None            None
# 2      None            None
# 3      None            None
# 4      None            None
#
#                                               fileID flightDirection  \
# 0  OPERA_L2_CSLC-S1_T124-264311-IW2_20231226T0431...       ASCENDING
# 1  OPERA_L2_CSLC-S1_T124-264310-IW3_20231226T0431...       ASCENDING
# 2  OPERA_L2_CSLC-S1_T124-264310-IW2_20231226T0431...       ASCENDING
# 3  OPERA_L2_CSLC-S1_T124-264309-IW3_20231226T0431...       ASCENDING
# 4  OPERA_L2_CSLC-S1_T124-264309-IW2_20231226T0431...       ASCENDING
#
#                          groupID granuleType insarStackId md5sum  \
# 0  S1A_IWDV_0062_0067_051821_124        None         None   None
# 1  S1A_IWDV_0062_0067_051821_124        None         None   None
# 2  S1A_IWDV_0062_0067_051821_124        None         None   None
# 3  S1A_IWDV_0062_0067_051821_124        None         None   None
# 4  S1A_IWDV_0062_0067_051821_124        None         None   None
#
#   offNadirAngle  orbit  pathNumber     platform pointingAngle polarization  \
# 0          None  51821         124  Sentinel-1A          None         [VV]
# 1          None  51821         124  Sentinel-1A          None         [VV]
# 2          None  51821         124  Sentinel-1A          None         [VV]
# 3          None  51821         124  Sentinel-1A          None         [VV]
# 4          None  51821         124  Sentinel-1A          None         [VV]
#
#          processingDate processingLevel  \
# 0  2023-12-27T08:13:33Z            CSLC
# 1  2023-12-27T08:24:38Z            CSLC
# 2  2023-12-27T08:12:07Z            CSLC
# 3  2023-12-27T08:23:22Z            CSLC
# 4  2023-12-27T08:10:42Z            CSLC
#
#                                            sceneName sensor  \
# 0  OPERA_L2_CSLC-S1_T124-264311-IW2_20231226T0431...  C-SAR
# 1  OPERA_L2_CSLC-S1_T124-264310-IW3_20231226T0431...  C-SAR
# 2  OPERA_L2_CSLC-S1_T124-264310-IW2_20231226T0431...  C-SAR
# 3  OPERA_L2_CSLC-S1_T124-264309-IW3_20231226T0431...  C-SAR
# 4  OPERA_L2_CSLC-S1_T124-264309-IW2_20231226T0431...  C-SAR
#
#               startTime              stopTime  \
# 0  2023-12-26T04:31:33Z  2023-12-26T04:31:36Z
# 1  2023-12-26T04:31:31Z  2023-12-26T04:31:34Z
# 2  2023-12-26T04:31:30Z  2023-12-26T04:31:33Z
# 3  2023-12-26T04:31:28Z  2023-12-26T04:31:31Z
# 4  2023-12-26T04:31:27Z  2023-12-26T04:31:30Z
#
#                                                  url pgeVersion  \
# 0  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...      2.1.0
# 1  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...      2.1.0
# 2  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...      2.1.0
# 3  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...      2.1.0
# 4  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...      2.1.0
#
#                                             fileName frameNumber beamMode  \
# 0  OPERA_L2_CSLC-S1_T124-264311-IW2_20231226T0431...        None       IW
# 1  OPERA_L2_CSLC-S1_T124-264310-IW3_20231226T0431...        None       IW
# 2  OPERA_L2_CSLC-S1_T124-264310-IW2_20231226T0431...        None       IW
# 3  OPERA_L2_CSLC-S1_T124-264309-IW3_20231226T0431...        None       IW
# 4  OPERA_L2_CSLC-S1_T124-264309-IW2_20231226T0431...        None       IW
#
#                                       additionalUrls     operaBurstID
# 0  [https://datapool.asf.alaska.edu/CSLC/OPERA-S1...  T124_264311_IW2
# 1  [https://datapool.asf.alaska.edu/CSLC/OPERA-S1...  T124_264310_IW3
# 2  [https://datapool.asf.alaska.edu/CSLC/OPERA-S1...  T124_264310_IW2
# 3  [https://datapool.asf.alaska.edu/CSLC/OPERA-S1...  T124_264309_IW3
# 4  [https://datapool.asf.alaska.edu/CSLC/OPERA-S1...  T124_264309_IW2

# %%
## Filter data based on specified track number
gf = gf[gf.pathNumber==pathNumber]
cslc = gf[['operaBurstID','startTime', 'stopTime', 'url', 'geometry']]
cslc['startTime'] = pd.to_datetime(cslc.startTime).dt.date
cslc['stopTime'] = pd.to_datetime(cslc.stopTime).dt.date
cslc = cslc.drop_duplicates(subset=['operaBurstID', 'startTime'], ignore_index=True)
cslc
# Out:
#        operaBurstID   startTime    stopTime  \
# 0   T124_264311_IW2  2023-12-26  2023-12-26
# 1   T124_264310_IW3  2023-12-26  2023-12-26
# 2   T124_264310_IW2  2023-12-26  2023-12-26
# 3   T124_264309_IW3  2023-12-26  2023-12-26
# 4   T124_264309_IW2  2023-12-26  2023-12-26
# 5   T124_264308_IW3  2023-12-26  2023-12-26
# 6   T124_264308_IW2  2023-12-26  2023-12-26
# 7   T124_264307_IW3  2023-12-26  2023-12-26
# 8   T124_264307_IW2  2023-12-26  2023-12-26
# 9   T124_264306_IW3  2023-12-26  2023-12-26
# 10  T124_264306_IW2  2023-12-26  2023-12-26
# 11  T124_264305_IW3  2023-12-26  2023-12-26
# 12  T124_264305_IW2  2023-12-26  2023-12-26
# 13  T124_264304_IW3  2023-12-26  2023-12-26
# 14  T124_264304_IW2  2023-12-26  2023-12-26
# 15  T124_264303_IW3  2023-12-26  2023-12-26
# 16  T124_264303_IW2  2023-12-26  2023-12-26
# 17  T124_264302_IW3  2023-12-26  2023-12-26
# 18  T124_264311_IW2  2023-12-14  2023-12-14
# 19  T124_264310_IW3  2023-12-14  2023-12-14
# 20  T124_264310_IW2  2023-12-14  2023-12-14
# 21  T124_264309_IW3  2023-12-14  2023-12-14
# 22  T124_264309_IW2  2023-12-14  2023-12-14
# 23  T124_264308_IW3  2023-12-14  2023-12-14
# 24  T124_264308_IW2  2023-12-14  2023-12-14
# 25  T124_264307_IW3  2023-12-14  2023-12-14
# 26  T124_264307_IW2  2023-12-14  2023-12-14
# 27  T124_264306_IW3  2023-12-14  2023-12-14
# 28  T124_264306_IW2  2023-12-14  2023-12-14
# 29  T124_264305_IW3  2023-12-14  2023-12-14
# 30  T124_264305_IW2  2023-12-14  2023-12-14
# 31  T124_264304_IW3  2023-12-14  2023-12-14
# 32  T124_264304_IW2  2023-12-14  2023-12-14
# 33  T124_264303_IW3  2023-12-14  2023-12-14
# 34  T124_264303_IW2  2023-12-14  2023-12-14
# 35  T124_264302_IW3  2023-12-14  2023-12-14
#
#                                                   url  \
# 0   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 1   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 2   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 3   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 4   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 5   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 6   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 7   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 8   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 9   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 10  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 11  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 12  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 13  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 14  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 15  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 16  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 17  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 18  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 19  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 20  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 21  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 22  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 23  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 24  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 25  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 26  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 27  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 28  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 29  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 30  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 31  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 32  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 33  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 34  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 35  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
#
#                                              geometry
# 0   POLYGON ((-156.15680 20.12214, -155.30759 20.2...
# 1   POLYGON ((-155.30681 20.16151, -154.55619 20.2...
# 2   POLYGON ((-156.12276 19.95542, -155.27450 20.1...
# 3   POLYGON ((-155.27364 19.99466, -154.52386 20.1...
# 4   POLYGON ((-156.08868 19.78844, -155.24136 19.9...
# 5   POLYGON ((-155.23062 19.82981, -154.49158 19.9...
# 6   POLYGON ((-156.05467 19.62171, -155.19841 19.7...
# 7   POLYGON ((-155.19627 19.66368, -154.45935 19.7...
# 8   POLYGON ((-156.02067 19.45498, -155.16404 19.6...
# 9   POLYGON ((-155.16279 19.49752, -154.42713 19.6...
# 10  POLYGON ((-155.98676 19.28861, -155.13406 19.4...
# 11  POLYGON ((-155.14140 19.32909, -154.39488 19.4...
# 12  POLYGON ((-155.95287 19.12223, -155.10919 19.2...
# 13  POLYGON ((-155.10836 19.16271, -154.36263 19.2...
# 14  POLYGON ((-155.91898 18.95586, -155.07619 19.1...
# 15  POLYGON ((-155.07529 18.99622, -154.33035 19.1...
# 16  POLYGON ((-155.88510 18.78948, -155.04319 18.9...
# 17  POLYGON ((-155.04225 18.82984, -154.29808 18.9...
# 18  POLYGON ((-156.15825 20.12361, -155.30906 20.2...
# 19  POLYGON ((-155.30826 20.16284, -154.55768 20.2...
# 20  POLYGON ((-156.12418 19.95676, -155.27595 20.1...
# 21  POLYGON ((-155.27510 19.99599, -154.52536 20.1...
# 22  POLYGON ((-156.09009 19.78965, -155.24279 19.9...
# 23  POLYGON ((-155.23208 19.83113, -154.49305 19.9...
# 24  POLYGON ((-156.05610 19.62305, -155.19986 19.7...
# 25  POLYGON ((-155.19770 19.66488, -154.46079 19.7...
# 26  POLYGON ((-156.02213 19.45643, -155.16552 19.6...
# 27  POLYGON ((-155.16417 19.49848, -154.42852 19.6...
# 28  POLYGON ((-155.98817 19.28982, -155.13549 19.4...
# 29  POLYGON ((-155.14278 19.33004, -154.39628 19.4...
# 30  POLYGON ((-155.95422 19.12319, -155.11057 19.2...
# 31  POLYGON ((-155.10976 19.16379, -154.36405 19.2...
# 32  POLYGON ((-155.92033 18.95682, -155.07757 19.1...
# 33  POLYGON ((-155.07669 18.99729, -154.33177 19.1...
# 34  POLYGON ((-155.88646 18.79044, -155.04457 18.9...
# 35  POLYGON ((-155.04365 18.83091, -154.29950 18.9...

# %%
## Choose the reference and secondary dates
ref = referenceDate.date()
sec = secondaryDate.date()

print(f'Reference Date: {ref}')
print(f'Secondary Date: {sec}')

## Drop other dates
cslc = cslc.loc[cslc.startTime.isin([ref,sec])]
cslc
# Out:
# Reference Date: 2023-12-14
# Secondary Date: 2023-12-26
#        operaBurstID   startTime    stopTime  \
# 0   T124_264311_IW2  2023-12-26  2023-12-26
# 1   T124_264310_IW3  2023-12-26  2023-12-26
# 2   T124_264310_IW2  2023-12-26  2023-12-26
# 3   T124_264309_IW3  2023-12-26  2023-12-26
# 4   T124_264309_IW2  2023-12-26  2023-12-26
# 5   T124_264308_IW3  2023-12-26  2023-12-26
# 6   T124_264308_IW2  2023-12-26  2023-12-26
# 7   T124_264307_IW3  2023-12-26  2023-12-26
# 8   T124_264307_IW2  2023-12-26  2023-12-26
# 9   T124_264306_IW3  2023-12-26  2023-12-26
# 10  T124_264306_IW2  2023-12-26  2023-12-26
# 11  T124_264305_IW3  2023-12-26  2023-12-26
# 12  T124_264305_IW2  2023-12-26  2023-12-26
# 13  T124_264304_IW3  2023-12-26  2023-12-26
# 14  T124_264304_IW2  2023-12-26  2023-12-26
# 15  T124_264303_IW3  2023-12-26  2023-12-26
# 16  T124_264303_IW2  2023-12-26  2023-12-26
# 17  T124_264302_IW3  2023-12-26  2023-12-26
# 18  T124_264311_IW2  2023-12-14  2023-12-14
# 19  T124_264310_IW3  2023-12-14  2023-12-14
# 20  T124_264310_IW2  2023-12-14  2023-12-14
# 21  T124_264309_IW3  2023-12-14  2023-12-14
# 22  T124_264309_IW2  2023-12-14  2023-12-14
# 23  T124_264308_IW3  2023-12-14  2023-12-14
# 24  T124_264308_IW2  2023-12-14  2023-12-14
# 25  T124_264307_IW3  2023-12-14  2023-12-14
# 26  T124_264307_IW2  2023-12-14  2023-12-14
# 27  T124_264306_IW3  2023-12-14  2023-12-14
# 28  T124_264306_IW2  2023-12-14  2023-12-14
# 29  T124_264305_IW3  2023-12-14  2023-12-14
# 30  T124_264305_IW2  2023-12-14  2023-12-14
# 31  T124_264304_IW3  2023-12-14  2023-12-14
# 32  T124_264304_IW2  2023-12-14  2023-12-14
# 33  T124_264303_IW3  2023-12-14  2023-12-14
# 34  T124_264303_IW2  2023-12-14  2023-12-14
# 35  T124_264302_IW3  2023-12-14  2023-12-14
#
#                                                   url  \
# 0   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 1   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 2   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 3   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 4   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 5   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 6   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 7   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 8   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 9   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 10  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 11  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 12  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 13  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 14  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 15  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 16  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 17  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 18  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 19  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 20  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 21  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 22  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 23  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 24  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 25  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 26  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 27  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 28  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 29  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 30  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 31  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 32  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 33  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 34  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 35  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
#
#                                              geometry
# 0   POLYGON ((-156.15680 20.12214, -155.30759 20.2...
# 1   POLYGON ((-155.30681 20.16151, -154.55619 20.2...
# 2   POLYGON ((-156.12276 19.95542, -155.27450 20.1...
# 3   POLYGON ((-155.27364 19.99466, -154.52386 20.1...
# 4   POLYGON ((-156.08868 19.78844, -155.24136 19.9...
# 5   POLYGON ((-155.23062 19.82981, -154.49158 19.9...
# 6   POLYGON ((-156.05467 19.62171, -155.19841 19.7...
# 7   POLYGON ((-155.19627 19.66368, -154.45935 19.7...
# 8   POLYGON ((-156.02067 19.45498, -155.16404 19.6...
# 9   POLYGON ((-155.16279 19.49752, -154.42713 19.6...
# 10  POLYGON ((-155.98676 19.28861, -155.13406 19.4...
# 11  POLYGON ((-155.14140 19.32909, -154.39488 19.4...
# 12  POLYGON ((-155.95287 19.12223, -155.10919 19.2...
# 13  POLYGON ((-155.10836 19.16271, -154.36263 19.2...
# 14  POLYGON ((-155.91898 18.95586, -155.07619 19.1...
# 15  POLYGON ((-155.07529 18.99622, -154.33035 19.1...
# 16  POLYGON ((-155.88510 18.78948, -155.04319 18.9...
# 17  POLYGON ((-155.04225 18.82984, -154.29808 18.9...
# 18  POLYGON ((-156.15825 20.12361, -155.30906 20.2...
# 19  POLYGON ((-155.30826 20.16284, -154.55768 20.2...
# 20  POLYGON ((-156.12418 19.95676, -155.27595 20.1...
# 21  POLYGON ((-155.27510 19.99599, -154.52536 20.1...
# 22  POLYGON ((-156.09009 19.78965, -155.24279 19.9...
# 23  POLYGON ((-155.23208 19.83113, -154.49305 19.9...
# 24  POLYGON ((-156.05610 19.62305, -155.19986 19.7...
# 25  POLYGON ((-155.19770 19.66488, -154.46079 19.7...
# 26  POLYGON ((-156.02213 19.45643, -155.16552 19.6...
# 27  POLYGON ((-155.16417 19.49848, -154.42852 19.6...
# 28  POLYGON ((-155.98817 19.28982, -155.13549 19.4...
# 29  POLYGON ((-155.14278 19.33004, -154.39628 19.4...
# 30  POLYGON ((-155.95422 19.12319, -155.11057 19.2...
# 31  POLYGON ((-155.10976 19.16379, -154.36405 19.2...
# 32  POLYGON ((-155.92033 18.95682, -155.07757 19.1...
# 33  POLYGON ((-155.07669 18.99729, -154.33177 19.1...
# 34  POLYGON ((-155.88646 18.79044, -155.04457 18.9...
# 35  POLYGON ((-155.04365 18.83091, -154.29950 18.9...

# %%
## Ensure that you have 2 cslcs per operaBurstID
cslc.operaBurstID.value_counts()
# Out:
# operaBurstID
# T124_264311_IW2    2
# T124_264310_IW3    2
# T124_264303_IW2    2
# T124_264303_IW3    2
# T124_264304_IW2    2
# T124_264304_IW3    2
# T124_264305_IW2    2
# T124_264305_IW3    2
# T124_264306_IW2    2
# T124_264306_IW3    2
# T124_264307_IW2    2
# T124_264307_IW3    2
# T124_264308_IW2    2
# T124_264308_IW3    2
# T124_264309_IW2    2
# T124_264309_IW3    2
# T124_264310_IW2    2
# T124_264302_IW3    2
# Name: count, dtype: int64

# %%
## Keep only bursts that have at least 2 counts of data
counts = cslc.operaBurstID.value_counts()
cslc = cslc.loc[~cslc['operaBurstID'].isin(counts[counts < 2].index)].reset_index(drop=True)
cslc
# Out:
#        operaBurstID   startTime    stopTime  \
# 0   T124_264311_IW2  2023-12-26  2023-12-26
# 1   T124_264310_IW3  2023-12-26  2023-12-26
# 2   T124_264310_IW2  2023-12-26  2023-12-26
# 3   T124_264309_IW3  2023-12-26  2023-12-26
# 4   T124_264309_IW2  2023-12-26  2023-12-26
# 5   T124_264308_IW3  2023-12-26  2023-12-26
# 6   T124_264308_IW2  2023-12-26  2023-12-26
# 7   T124_264307_IW3  2023-12-26  2023-12-26
# 8   T124_264307_IW2  2023-12-26  2023-12-26
# 9   T124_264306_IW3  2023-12-26  2023-12-26
# 10  T124_264306_IW2  2023-12-26  2023-12-26
# 11  T124_264305_IW3  2023-12-26  2023-12-26
# 12  T124_264305_IW2  2023-12-26  2023-12-26
# 13  T124_264304_IW3  2023-12-26  2023-12-26
# 14  T124_264304_IW2  2023-12-26  2023-12-26
# 15  T124_264303_IW3  2023-12-26  2023-12-26
# 16  T124_264303_IW2  2023-12-26  2023-12-26
# 17  T124_264302_IW3  2023-12-26  2023-12-26
# 18  T124_264311_IW2  2023-12-14  2023-12-14
# 19  T124_264310_IW3  2023-12-14  2023-12-14
# 20  T124_264310_IW2  2023-12-14  2023-12-14
# 21  T124_264309_IW3  2023-12-14  2023-12-14
# 22  T124_264309_IW2  2023-12-14  2023-12-14
# 23  T124_264308_IW3  2023-12-14  2023-12-14
# 24  T124_264308_IW2  2023-12-14  2023-12-14
# 25  T124_264307_IW3  2023-12-14  2023-12-14
# 26  T124_264307_IW2  2023-12-14  2023-12-14
# 27  T124_264306_IW3  2023-12-14  2023-12-14
# 28  T124_264306_IW2  2023-12-14  2023-12-14
# 29  T124_264305_IW3  2023-12-14  2023-12-14
# 30  T124_264305_IW2  2023-12-14  2023-12-14
# 31  T124_264304_IW3  2023-12-14  2023-12-14
# 32  T124_264304_IW2  2023-12-14  2023-12-14
# 33  T124_264303_IW3  2023-12-14  2023-12-14
# 34  T124_264303_IW2  2023-12-14  2023-12-14
# 35  T124_264302_IW3  2023-12-14  2023-12-14
#
#                                                   url  \
# 0   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 1   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 2   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 3   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 4   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 5   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 6   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 7   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 8   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 9   https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 10  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 11  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 12  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 13  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 14  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 15  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 16  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 17  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 18  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 19  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 20  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 21  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 22  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 23  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 24  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 25  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 26  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 27  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 28  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 29  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 30  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 31  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 32  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 33  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 34  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
# 35  https://datapool.asf.alaska.edu/CSLC/OPERA-S1/...
#
#                                              geometry
# 0   POLYGON ((-156.15680 20.12214, -155.30759 20.2...
# 1   POLYGON ((-155.30681 20.16151, -154.55619 20.2...
# 2   POLYGON ((-156.12276 19.95542, -155.27450 20.1...
# 3   POLYGON ((-155.27364 19.99466, -154.52386 20.1...
# 4   POLYGON ((-156.08868 19.78844, -155.24136 19.9...
# 5   POLYGON ((-155.23062 19.82981, -154.49158 19.9...
# 6   POLYGON ((-156.05467 19.62171, -155.19841 19.7...
# 7   POLYGON ((-155.19627 19.66368, -154.45935 19.7...
# 8   POLYGON ((-156.02067 19.45498, -155.16404 19.6...
# 9   POLYGON ((-155.16279 19.49752, -154.42713 19.6...
# 10  POLYGON ((-155.98676 19.28861, -155.13406 19.4...
# 11  POLYGON ((-155.14140 19.32909, -154.39488 19.4...
# 12  POLYGON ((-155.95287 19.12223, -155.10919 19.2...
# 13  POLYGON ((-155.10836 19.16271, -154.36263 19.2...
# 14  POLYGON ((-155.91898 18.95586, -155.07619 19.1...
# 15  POLYGON ((-155.07529 18.99622, -154.33035 19.1...
# 16  POLYGON ((-155.88510 18.78948, -155.04319 18.9...
# 17  POLYGON ((-155.04225 18.82984, -154.29808 18.9...
# 18  POLYGON ((-156.15825 20.12361, -155.30906 20.2...
# 19  POLYGON ((-155.30826 20.16284, -154.55768 20.2...
# 20  POLYGON ((-156.12418 19.95676, -155.27595 20.1...
# 21  POLYGON ((-155.27510 19.99599, -154.52536 20.1...
# 22  POLYGON ((-156.09009 19.78965, -155.24279 19.9...
# 23  POLYGON ((-155.23208 19.83113, -154.49305 19.9...
# 24  POLYGON ((-156.05610 19.62305, -155.19986 19.7...
# 25  POLYGON ((-155.19770 19.66488, -154.46079 19.7...
# 26  POLYGON ((-156.02213 19.45643, -155.16552 19.6...
# 27  POLYGON ((-155.16417 19.49848, -154.42852 19.6...
# 28  POLYGON ((-155.98817 19.28982, -155.13549 19.4...
# 29  POLYGON ((-155.14278 19.33004, -154.39628 19.4...
# 30  POLYGON ((-155.95422 19.12319, -155.11057 19.2...
# 31  POLYGON ((-155.10976 19.16379, -154.36405 19.2...
# 32  POLYGON ((-155.92033 18.95682, -155.07757 19.1...
# 33  POLYGON ((-155.07669 18.99729, -154.33177 19.1...
# 34  POLYGON ((-155.88646 18.79044, -155.04457 18.9...
# 35  POLYGON ((-155.04365 18.83091, -154.29950 18.9...

# %%
## Basemap function for Folium
def getbasemaps():
    # Add custom base maps to folium
    basemaps = {
        'Google Satellite Hybrid': folium.TileLayer(
            tiles = 'https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
            attr = 'Google',
            name = 'Google Satellite',
            overlay = True,
            control = True,
            # opacity = 0.8,
            show = False
        ),
        'Esri Satellite': folium.TileLayer(
            tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
            attr = 'Esri',
            name = 'Esri Satellite',
            overlay = True,
            control = True,
            #opacity = 0.8,
            show = False
        )
    }
    return basemaps

# %%
# Interactive map to visualize the boundaries of the selected OPERA CSLCs
m = folium.Map(location=[aoi.centroid.y, aoi.centroid.x], zoom_start=4, tiles="CartoDB positron")

# Add custom basemaps
basemaps = getbasemaps()
for basemap in basemaps:
    basemaps[basemap].add_to(m)

# layer Control
m.add_child(folium.LayerControl())

## RLE sites
for _, r in cslc.iterrows():
    sim_geo = gpd.GeoSeries(r["geometry"]).simplify(tolerance=0.001)
    geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"color": "red"}, control=False)
    folium.Popup(r["operaBurstID"]).add_to(geo_j)
    geo_j.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b8e019a09ea33c5bda353cf1e982974 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b8e019a09ea33c5bda353cf1e982974&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b8e019a09ea33c5bda353cf1e982974 = L.map(
#                 &quot;map_8b8e019a09ea33c5bda353cf1e982974&quot;,
#                 {
#                     center: [19.598100000000002, -155.447],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2df02597a143c3d98a3930b0d26219a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b2df02597a143c3d98a3930b0d26219a.addTo(map_8b8e019a09ea33c5bda353cf1e982974);
#
#
#             var tile_layer_f717d609cf8a9d1623259a66db0745d7 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_4ac6a4fa408decd0db37d52cabe203d9 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var layer_control_b23b0e7701ed82238cade3003a500a6c_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_b2df02597a143c3d98a3930b0d26219a,
#                 },
#                 overlays :  {
#                     &quot;Google Satellite&quot; : tile_layer_f717d609cf8a9d1623259a66db0745d7,
#                     &quot;Esri Satellite&quot; : tile_layer_4ac6a4fa408decd0db37d52cabe203d9,
#                 },
#             };
#             let layer_control_b23b0e7701ed82238cade3003a500a6c = L.control.layers(
#                 layer_control_b23b0e7701ed82238cade3003a500a6c_layers.base_layers,
#                 layer_control_b23b0e7701ed82238cade3003a500a6c_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_8b8e019a09ea33c5bda353cf1e982974);
#
#
#
#         function geo_json_04c6fbb1b6a833a53636a517419ae963_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;};
#             }
#         }
#
#         function geo_json_04c6fbb1b6a833a53636a517419ae963_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_04c6fbb1b6a833a53636a517419ae963 = L.geoJson(null, {
#                 onEachFeature: geo_json_04c6fbb1b6a833a53636a517419ae963_onEachFeature,
#
#                 style: geo_json_04c6fbb1b6a833a53636a517419ae963_styler,
#         });
#
#         function geo_json_04c6fbb1b6a833a53636a517419ae963_add (data) {
#             geo_json_04c6fbb1b6a833a53636a517419ae963
#                 .addData(data);
#         }
#             geo_json_04c6fbb1b6a833a53636a517419ae963_add({&quot;bbox&quot;: [-156.19075, 20.12214, -155.30759, 20.44007], &quot;features&quot;: [{&quot;bbox&quot;: [-156.19075, 20.12214, -155.30759, 20.44007], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-156.1568, 20.12214], [-155.30759, 20.27397], [-155.34058, 20.44007], [-156.19075, 20.28837], [-156.1568, 20.12214]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         var popup_1be866a004fd271884e111597de2fd0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c94b53630d7fcc37ff794b2f1eaeba3 = $(`&lt;div id=&quot;html_2c94b53630d7fcc37ff794b2f1eaeba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;T124_264311_IW2&lt;/div&gt;`)[0];
#                 popup_1be866a004fd271884e111597de2fd0f.setContent(html_2c94b53630d7fcc37ff794b2f1eaeba3);
#
#
#
#         geo_json_04c6fbb1b6a833a53636a517419ae963.bindPopup(popup_1be866a004fd271884e111597de2fd0f)
#         ;
#
#
#
#
#             geo_json_04c6fbb1b6a833a53636a517419ae963.addTo(map_8b8e019a09ea33c5bda353cf1e982974);
#
#
#         function geo_j

# %%
## Download the relevant OPERA CSLCs to a temporary "cslc" folder 
os.makedirs(f'{savedir}/cslc', exist_ok='True')
asf.download_urls(urls=cslc.url, path=f'{savedir}/cslc', processes=10)

# %% [markdown]
# ## 3. Create burst-wise IFGs, stitch, and unwrap using Dolphin

# %%
# Go to the working/save directory
os.chdir(f'{savedir}')

# %%
# # Create waterMask if waterMask is not available
# # You must install isce2, mintpy, and gdal
# # Run wbd.py from isce2, generate mask using from MintPy, crop mask to the same area extent of the IFG using gdalwarp

# !wbd.py 18 21 -157 -154
# !generate_mask.py swbdLat_N18_N21_Lon_W157_W154.wbd --max 0.5 -o waterMask.h5
# !save_gdal.py waterMask.h5 -o waterMask.tif
# !gdalwarp -t_srs EPSG:32605 -te 161040.0000000000000000 2075280.0000000000000000 368430.0000000000000000 2271570.0000000000000000 waterMask.tif sub_waterMask_utm.tif -ot Byte -overwrite -tr 30 -30

# %%
# # For this Big Island case, ensure you have the mask_file.
dconfig.create_config(outfile='dolphin_config.yaml', slc_files='./cslc/*.h5',\
                      subdataset='/data/VV', strides=[6, 3], n_workers=4, n_parallel_bursts=2, threads_per_worker= 16, mask_file='./WBD/sub_waterMask_utm.tif')

# # No unwrapping option: --no-unwrap=True
# dconfig.create_config(outfile='dolphin_config.yaml', slc_files='./cslc/*.h5',\
#                       subdataset='/data/VV', strides=[6, 3], n_workers=2, threads_per_worker=16,  mask_file='./WBD/sub_waterMask_utm.tif', no_unwrap=True)

## Via command line input
# !dolphin config --slc-files ./cslc/*.h5 --subdataset "/data/VV" --strides 6 3 --n-workers 2 --threads-per-worker 16 --mask-file './WBD/sub_waterMask_utm.tif'
# !dolphin config --slc-files ./cslc/*.h5 --subdataset "/data/VV" --strides 6 3 --n-workers 2 --threads-per-worker 16 --mask-file './WBD/sub_waterMask_utm.tif' --no-unwrap
# Out:
# Saving configuration to dolphin_config.yaml

# %%
# %%time
drun.run('dolphin_config.yaml')

## Via command line input
# !dolphin run dolphin_config.yaml
# Out:
# [2024-01-17 16:30:13] INFO     Found SLC files from 18 bursts                                    ]8;id=531582;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/displacement.py\displacement.py]8;;\:]8;id=6861;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/displacement.py#76\76]8;;\
# [2024-01-17 16:30:14] INFO     Running wrapped phase         ]8;id=674191;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=617197;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#47\47]8;;\
#                                estimation in
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264302_iw3
# [2024-01-17 16:30:14] INFO     Running wrapped phase         ]8;id=236623;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=742282;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#47\47]8;;\
#                                estimation in
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264303_iw2
# [2024-01-17 16:30:15] INFO     Creating persistent scatterer ]8;id=211610;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=680166;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#69\69]8;;\
#                                file
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264302_iw3/PS/
#                                ps_pixels.tif
# [2024-01-17 16:30:15] INFO     Creating persistent scatterer ]8;id=578432;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=249053;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#69\69]8;;\
#                                file
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264303_iw2/PS/
#                                ps_pixels.tif
#   370/370 Processing (512, 512) sized blocks... ━━━━━━━━━━━━━━━━━━━ 100% 0:00:16m 0:00:1600:16
# ⠧ 369/410 Processing (512, 512) sized blocks... ━━━━━━━━━━━━━━━━━╺━  90% 0:00:17[2024-01-17 16:30:32] INFO     Waiting to write 0 blocks of data.      ]8;id=826423;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=866457;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#150\150]8;;\
# ⠇ 372/410 Processing (512, 512) sized blocks... ━━━━━━━━━━━━━━━━━╺━  91% 0:00:17                      INFO     Finished writing out PS files           ]8;id=138560;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=172527;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#152\152]8;;\
#                       INFO     Saving a looked PS mask to              ]8;id=885166;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=849144;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#283\283]8;;\
#                                /u/trappist-r0/bato/work/OPERA_Applicat
#                                ions/CSLC/Discover/BigIsland/t124_26430
#                                2_iw3/PS/ps_pixels_looked.tif
#   410/410 Processing (512, 512) sized blocks... ━━━━━━━━━━━━━━━━━━━ 100% 0:00:18m 0:00:1800:17
# [2024-01-17 16:30:34] INFO     Waiting to write 0 blocks of data.      ]8;id=749064;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=271119;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#150\150]8;;\
#                       INFO     Finished writing out PS files           ]8;id=341917;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=124831;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#152\152]8;;\
#                       INFO     Saving a looked PS mask to              ]8;id=801342;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=725274;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#283\283]8;;\
#                                /u/trappist-r0/bato/work/OPERA_Applicat
#                                ions/CSLC/Discover/BigIsland/t124_26430
#                                3_iw2/PS/ps_pixels_looked.tif
# [2024-01-17 16:30:39] INFO     Running sequential EMI step  ]8;id=277939;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=198259;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#138\138]8;;\
#                                in
#                                /u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264302_iw3/
#                                linked_phase
#                       INFO     Full file range for VRTStack(2   ]8;id=349924;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=994294;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#59\59]8;;\
#                                bands,
#                                outfile=/u/trappist-r0/bato/work
#                                /OPERA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264302_iw3/slc_
#                                stack.vrt): from
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64302-IW3_20231214T043110Z_20231
#                                215T165006Z_S1A_VV_v1.0.h5 to
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64302-IW3_20231226T043109Z_20231
#                                227T075547Z_S1A_VV_v1.0.h5
#                       INFO     Output folder:                   ]8;id=811592;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=372207;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#62\62]8;;\
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264302_iw3/linked_phase
#                       INFO     Number of ministacks of size 15: ]8;id=303229;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=749477;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#63\63]8;;\
#                                1
#                       INFO     Processing 2 SLCs. Output        ]8;id=714315;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=739098;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#86\86]8;;\
#                                folder:
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264302_iw3/linked_phase
#                                /20231214_20231226
#                       INFO     VRTStack(2 bands,                    ]8;id=947996;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=731224;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#80\80]8;;\
#                                outfile=/u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discover/BigIsl
#                                and/t124_264302_iw3/linked_phase/202
#                                31214_20231226.vrt): from
#                                [datetime.datetime(2023, 12, 14, 0,
#                                0)]
#                                /u/trappist-r0/bato/work/OPERA_Appli
#                                cations/CSLC/Discover/BigIsland/cslc
#                                /OPERA_L2_CSLC-S1_T124-264302-IW3_20
#                                231226T043109Z_20231227T075547Z_S1A_
#                                VV_v1.0.h5
# [2024-01-17 16:30:40] INFO     Running sequential EMI step  ]8;id=705350;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=854528;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#138\138]8;;\
#                                in
#                                /u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264303_iw2/
#                                linked_phase
# [2024-01-17 16:30:41] INFO     Full file range for VRTStack(2   ]8;id=439598;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=805145;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#59\59]8;;\
#                                bands,
#                                outfile=/u/trappist-r0/bato/work
#                                /OPERA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264303_iw2/slc_
#                                stack.vrt): from
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64303-IW2_20231214T043112Z_20231
#                                215T165006Z_S1A_VV_v1.0.h5 to
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64303-IW2_20231226T043111Z_20231
#                                227T075547Z_S1A_VV_v1.0.h5
#                       INFO     Output folder:                   ]8;id=216932;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=104041;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#62\62]8;;\
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264303_iw2/linked_phase
#                       INFO     Number of ministacks of size 15: ]8;id=651864;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=555339;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#63\63]8;;\
#                                1
#                       INFO     Processing 2 SLCs. Output        ]8;id=116865;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=84877;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#86\86]8;;\
#                                folder:
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264303_iw2/linked_phase
#                                /20231214_20231226
#                       INFO     VRTStack(2 bands,                    ]8;id=929102;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=327853;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#80\80]8;;\
#                                outfile=/u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discover/BigIsl
#                                and/t124_264303_iw2/linked_phase/202
#                                31214_20231226.vrt): from
#                                [datetime.datetime(2023, 12, 14, 0,
#                                0)]
#                                /u/trappist-r0/bato/work/OPERA_Appli
#                                cations/CSLC/Discover/BigIsland/cslc
#                                /OPERA_L2_CSLC-S1_T124-264303-IW2_20
#                                231226T043111Z_20231227T075547Z_S1A_
#                                VV_v1.0.h5
# [2024-01-17 16:30:44] INFO     Processing 2 SLCs + 0 compressed    ]8;id=926557;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=580435;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#100\100]8;;\
#                                SLCs.
#                       INFO     Total stack size (in pixels): (2,   ]8;id=292160;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=588522;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#105\105]8;;\
#                                4611, 18552)
#                       INFO     Iterating over (512, 512) blocks,   ]8;id=570045;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=912156;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#155\155]8;;\
#                                370 total
# [2024-01-17 16:30:47] INFO     Processing 2 SLCs + 0 compressed    ]8;id=512553;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=682539;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#100\100]8;;\
#                                SLCs.
#                       INFO     Total stack size (in pixels): (2,   ]8;id=718848;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=126854;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#105\105]8;;\
#                                4665, 20586)
#                       INFO     Iterating over (512, 512) blocks,   ]8;id=272831;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=872632;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#155\155]8;;\
#                                410 total
# [2024-01-17 16:33:43] INFO     Waiting to write 0 blocks of data.  ]8;id=779705;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=86099;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#266\266]8;;\
#                       INFO     Finished ministack of size (2,      ]8;id=165701;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=572752;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#268\268]8;;\
#                                4611, 18552).
#                       INFO     Creating virtual             ]8;id=494197;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=499534;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#178\178]8;;\
#                                interferograms from 2 files
#                       INFO     Total elapsed time for                ]8;id=229016;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py\_log.py]8;;\:]8;id=89638;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py#118\118]8;;\
#                                dolphin.workflows.wrapped_phase.run :
#                                3.48 minutes (208.95 seconds)
#                       INFO     Running wrapped phase         ]8;id=397373;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=452238;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#47\47]8;;\
#                                estimation in
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264303_iw3
#                       INFO     Creating persistent scatterer ]8;id=208621;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=274489;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#69\69]8;;\
#                                file
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264303_iw3/PS/
#                                ps_pixels.tif
#   333/333 Processing (512, 512) sized blocks... ━━━━━━━━━━━━━━━━━━━ 100% 0:00:16m 0:00:1600:16
# [2024-01-17 16:34:01] INFO     Waiting to write 0 blocks of data.      ]8;id=312411;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=74157;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#150\150]8;;\
#                       INFO     Finished writing out PS files           ]8;id=500070;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=37195;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#152\152]8;;\
#                       INFO     Saving a looked PS mask to              ]8;id=447549;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=368235;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#283\283]8;;\
#                                /u/trappist-r0/bato/work/OPERA_Applicat
#                                ions/CSLC/Discover/BigIsland/t124_26430
#                                3_iw3/PS/ps_pixels_looked.tif
# [2024-01-17 16:34:04] INFO     Waiting to write 0 blocks of data.  ]8;id=102280;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=631021;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#266\266]8;;\
#                       INFO     Finished ministack of size (2,      ]8;id=125109;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=338480;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#268\268]8;;\
#                                4665, 20586).
#                       INFO     Creating virtual             ]8;id=64150;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=185739;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#178\178]8;;\
#                                interferograms from 2 files
#                       INFO     Total elapsed time for                ]8;id=968934;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py\_log.py]8;;\:]8;id=305664;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py#118\118]8;;\
#                                dolphin.workflows.wrapped_phase.run :
#                                3.83 minutes (229.82 seconds)
#                       INFO     Running wrapped phase         ]8;id=753724;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=438242;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#47\47]8;;\
#                                estimation in
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264304_iw2
#                       INFO     Creating persistent scatterer ]8;id=676956;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=857997;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#69\69]8;;\
#                                file
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264304_iw2/PS/
#                                ps_pixels.tif
# ⠼  55/410 Processing (512, 512) sized blocks... ━━╸━━━━━━━━━━━━━━━━  13% 0:00:02[2024-01-17 16:34:07] INFO     Running sequential EMI step  ]8;id=832134;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=339778;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#138\138]8;;\
#                                in
#                                /u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264303_iw3/
#                                linked_phase
# ⠴  57/410 Processing (512, 512) sized blocks... ━━╸━━━━━━━━━━━━━━━━  14% 0:00:02                      INFO     Full file range for VRTStack(2   ]8;id=264165;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=703463;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#59\59]8;;\
#                                bands,
#                                outfile=/u/trappist-r0/bato/work
#                                /OPERA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264303_iw3/slc_
#                                stack.vrt): from
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64303-IW3_20231214T043113Z_20231
#                                215T165006Z_S1A_VV_v1.0.h5 to
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64303-IW3_20231226T043112Z_20231
#                                227T075547Z_S1A_VV_v1.0.h5
#                       INFO     Output folder:                   ]8;id=26868;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=949920;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#62\62]8;;\
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264303_iw3/linked_phase
#                       INFO     Number of ministacks of size 15: ]8;id=507097;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=25334;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#63\63]8;;\
#                                1
#                       INFO     Processing 2 SLCs. Output        ]8;id=387794;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=193145;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#86\86]8;;\
#                                folder:
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264303_iw3/linked_phase
#                                /20231214_20231226
# ⠏  64/410 Processing (512, 512) sized blocks... ━━╸━━━━━━━━━━━━━━━━  16% 0:00:03[2024-01-17 16:34:08] INFO     VRTStack(2 bands,                    ]8;id=102347;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=450893;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#80\80]8;;\
#                                outfile=/u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discover/BigIsl
#                                and/t124_264303_iw3/linked_phase/202
#                                31214_20231226.vrt): from
#                                [datetime.datetime(2023, 12, 14, 0,
#                                0)]
#                                /u/trappist-r0/bato/work/OPERA_Appli
#                                cations/CSLC/Discover/BigIsland/cslc
#                                /OPERA_L2_CSLC-S1_T124-264303-IW3_20
#                                231226T043112Z_20231227T075547Z_S1A_
#                                VV_v1.0.h5
# ⠙ 154/410 Processing (512, 512) sized blocks... ━━━━━━━╺━━━━━━━━━━━  38% 0:00:08[2024-01-17 16:34:13] INFO     Processing 2 SLCs + 0 compressed    ]8;id=488154;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=943391;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#100\100]8;;\
#                                SLCs.
#                       INFO     Total stack size (in pixels): (2,   ]8;id=1867;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=615583;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#105\105]8;;\
#                                4608, 18558)
#                       INFO     Iterating over (512, 512) blocks,   ]8;id=11636;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=171481;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#155\155]8;;\
#                                370 total
#   410/410 Processing (512, 512) sized blocks... ━━━━━━━━━━━━━━━━━━━ 100% 0:00:19m 0:00:1900:18
# [2024-01-17 16:34:24] INFO     Waiting to write 0 blocks of data.      ]8;id=376000;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=167772;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#150\150]8;;\
# [2024-01-17 16:34:25] INFO     Finished writing out PS files           ]8;id=248564;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=248281;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#152\152]8;;\
#                       INFO     Saving a looked PS mask to              ]8;id=800816;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=219340;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#283\283]8;;\
#                                /u/trappist-r0/bato/work/OPERA_Applicat
#                                ions/CSLC/Discover/BigIsland/t124_26430
#                                4_iw2/PS/ps_pixels_looked.tif
# [2024-01-17 16:34:32] INFO     Running sequential EMI step  ]8;id=909232;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=250932;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#138\138]8;;\
#                                in
#                                /u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264304_iw2/
#                                linked_phase
#                       INFO     Full file range for VRTStack(2   ]8;id=523721;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=897511;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#59\59]8;;\
#                                bands,
#                                outfile=/u/trappist-r0/bato/work
#                                /OPERA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264304_iw2/slc_
#                                stack.vrt): from
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64304-IW2_20231214T043114Z_20231
#                                215T165006Z_S1A_VV_v1.0.h5 to
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64304-IW2_20231226T043114Z_20231
#                                227T075547Z_S1A_VV_v1.0.h5
#                       INFO     Output folder:                   ]8;id=834976;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=858993;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#62\62]8;;\
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264304_iw2/linked_phase
#                       INFO     Number of ministacks of size 15: ]8;id=601260;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=262445;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#63\63]8;;\
#                                1
#                       INFO     Processing 2 SLCs. Output        ]8;id=550872;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=895110;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#86\86]8;;\
#                                folder:
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264304_iw2/linked_phase
#                                /20231214_20231226
#                       INFO     VRTStack(2 bands,                    ]8;id=968434;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=464881;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#80\80]8;;\
#                                outfile=/u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discover/BigIsl
#                                and/t124_264304_iw2/linked_phase/202
#                                31214_20231226.vrt): from
#                                [datetime.datetime(2023, 12, 14, 0,
#                                0)]
#                                /u/trappist-r0/bato/work/OPERA_Appli
#                                cations/CSLC/Discover/BigIsland/cslc
#                                /OPERA_L2_CSLC-S1_T124-264304-IW2_20
#                                231226T043114Z_20231227T075547Z_S1A_
#                                VV_v1.0.h5
# [2024-01-17 16:34:38] INFO     Processing 2 SLCs + 0 compressed    ]8;id=853543;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=274120;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#100\100]8;;\
#                                SLCs.
#                       INFO     Total stack size (in pixels): (2,   ]8;id=54788;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=689827;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#105\105]8;;\
#                                4659, 20592)
#                       INFO     Iterating over (512, 512) blocks,   ]8;id=683135;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=676398;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#155\155]8;;\
#                                410 total
# [2024-01-17 16:37:08] INFO     Waiting to write 0 blocks of data.  ]8;id=600795;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=795454;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#266\266]8;;\
#                       INFO     Finished ministack of size (2,      ]8;id=650807;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=800225;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#268\268]8;;\
#                                4608, 18558).
# [2024-01-17 16:37:09] INFO     Creating virtual             ]8;id=527874;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=136183;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#178\178]8;;\
#                                interferograms from 2 files
#                       INFO     Total elapsed time for                ]8;id=997866;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py\_log.py]8;;\:]8;id=863537;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py#118\118]8;;\
#                                dolphin.workflows.wrapped_phase.run :
#                                3.42 minutes (205.33 seconds)
#                       INFO     Running wrapped phase         ]8;id=716064;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=985944;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#47\47]8;;\
#                                estimation in
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264304_iw3
#                       INFO     Creating persistent scatterer ]8;id=295798;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=511299;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#69\69]8;;\
#                                file
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264304_iw3/PS/
#                                ps_pixels.tif
#   333/333 Processing (512, 512) sized blocks... ━━━━━━━━━━━━━━━━━━━ 100% 0:00:17m 0:00:1700:16
# [2024-01-17 16:37:27] INFO     Waiting to write 0 blocks of data.      ]8;id=515523;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=413633;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#150\150]8;;\
#                       INFO     Finished writing out PS files           ]8;id=170826;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=653460;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#152\152]8;;\
#                       INFO     Saving a looked PS mask to              ]8;id=680755;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=804539;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#283\283]8;;\
#                                /u/trappist-r0/bato/work/OPERA_Applicat
#                                ions/CSLC/Discover/BigIsland/t124_26430
#                                4_iw3/PS/ps_pixels_looked.tif
# ...
#                                SLCs.
#                       INFO     Total stack size (in pixels): (2,   ]8;id=98755;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=400475;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#105\105]8;;\
#                                4656, 20592)
#                       INFO     Iterating over (512, 512) blocks,   ]8;id=861231;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=477642;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#155\155]8;;\
#                                410 total
# [2024-01-17 16:40:28] INFO     Waiting to write 0 blocks of data.  ]8;id=337187;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=590706;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#266\266]8;;\
#                       INFO     Finished ministack of size (2,      ]8;id=538708;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=217160;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#268\268]8;;\
#                                4605, 18552).
#                       INFO     Creating virtual             ]8;id=966469;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=624136;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#178\178]8;;\
#                                interferograms from 2 files
#                       INFO     Total elapsed time for                ]8;id=164732;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py\_log.py]8;;\:]8;id=563190;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py#118\118]8;;\
#                                dolphin.workflows.wrapped_phase.run :
#                                3.32 minutes (199.28 seconds)
#                       INFO     Running wrapped phase         ]8;id=777107;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=116129;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#47\47]8;;\
#                                estimation in
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264305_iw3
#                       INFO     Creating persistent scatterer ]8;id=598110;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=545158;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#69\69]8;;\
#                                file
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264305_iw3/PS/
#                                ps_pixels.tif
#   333/333 Processing (512, 512) sized blocks... ━━━━━━━━━━━━━━━━━━━ 100% 0:00:17m 0:00:1700:16
# [2024-01-17 16:40:46] INFO     Waiting to write 0 blocks of data.      ]8;id=807871;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=341427;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#150\150]8;;\
#                       INFO     Finished writing out PS files           ]8;id=507896;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=616193;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#152\152]8;;\
#                       INFO     Saving a looked PS mask to              ]8;id=100153;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py\ps.py]8;;\:]8;id=227278;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/ps.py#283\283]8;;\
#                                /u/trappist-r0/bato/work/OPERA_Applicat
#                                ions/CSLC/Discover/BigIsland/t124_26430
#                                5_iw3/PS/ps_pixels_looked.tif
# [2024-01-17 16:40:53] INFO     Running sequential EMI step  ]8;id=661739;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=251229;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#138\138]8;;\
#                                in
#                                /u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264305_iw3/
#                                linked_phase
#                       INFO     Full file range for VRTStack(2   ]8;id=791059;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=36118;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#59\59]8;;\
#                                bands,
#                                outfile=/u/trappist-r0/bato/work
#                                /OPERA_Applications/CSLC/Discove
#                                r/BigIsland/t124_264305_iw3/slc_
#                                stack.vrt): from
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64305-IW3_20231214T043118Z_20231
#                                215T165006Z_S1A_VV_v1.0.h5 to
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/cslc/OPERA_L2_CSLC-S1_T124-2
#                                64305-IW3_20231226T043117Z_20231
#                                227T075547Z_S1A_VV_v1.0.h5
#                       INFO     Output folder:                   ]8;id=417116;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=34651;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#62\62]8;;\
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264305_iw3/linked_phase
#                       INFO     Number of ministacks of size 15: ]8;id=465284;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=214167;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#63\63]8;;\
#                                1
#                       INFO     Processing 2 SLCs. Output        ]8;id=504046;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py\sequential.py]8;;\:]8;id=521747;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/sequential.py#86\86]8;;\
#                                folder:
#                                /u/trappist-r0/bato/work/OPERA_A
#                                pplications/CSLC/Discover/BigIsl
#                                and/t124_264305_iw3/linked_phase
#                                /20231214_20231226
# [2024-01-17 16:40:54] INFO     VRTStack(2 bands,                    ]8;id=241700;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=319732;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#80\80]8;;\
#                                outfile=/u/trappist-r0/bato/work/OPE
#                                RA_Applications/CSLC/Discover/BigIsl
#                                and/t124_264305_iw3/linked_phase/202
#                                31214_20231226.vrt): from
#                                [datetime.datetime(2023, 12, 14, 0,
#                                0)]
#                                /u/trappist-r0/bato/work/OPERA_Appli
#                                cations/CSLC/Discover/BigIsland/cslc
#                                /OPERA_L2_CSLC-S1_T124-264305-IW3_20
#                                231226T043117Z_20231227T075547Z_S1A_
#                                VV_v1.0.h5
# [2024-01-17 16:40:59] INFO     Processing 2 SLCs + 0 compressed    ]8;id=700979;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=562265;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#100\100]8;;\
#                                SLCs.
#                       INFO     Total stack size (in pixels): (2,   ]8;id=549966;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=531673;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#105\105]8;;\
#                                4602, 18558)
#                       INFO     Iterating over (512, 512) blocks,   ]8;id=631512;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=573252;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#155\155]8;;\
#                                333 total
# [2024-01-17 16:41:51] INFO     Waiting to write 0 blocks of data.  ]8;id=569664;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=558023;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#266\266]8;;\
# [2024-01-17 16:41:52] INFO     Finished ministack of size (2,      ]8;id=736928;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py\single.py]8;;\:]8;id=70842;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/single.py#268\268]8;;\
#                                4656, 20592).
#                       INFO     Creating virtual             ]8;id=250124;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=678205;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#178\178]8;;\
#                                interferograms from 2 files
#                       INFO     Total elapsed time for                ]8;id=624920;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py\_log.py]8;;\:]8;id=358080;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/_log.py#118\118]8;;\
#                                dolphin.workflows.wrapped_phase.run :
#                                3.96 minutes (237.55 seconds)
#                       INFO     Running wrapped phase         ]8;id=672964;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=89526;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#47\47]8;;\
#                                estimation in
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264306_iw2
#                       INFO     Creating persistent scatterer ]8;id=586971;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py\wrapped_phase.py]8;;\:]8;id=976024;file:///mnt/trappist-r0/bato/tools/anaconda3/envs/calval-DISP_dev/lib/python3.11/site-packages/dolphin/workflows/wrapped_phase.py#69\69]8;;\
#                                file
#                                /u/trappist-r0/bato/work/OPER
#                                A_Applications/CSLC/Discover/
#                                BigIsland/t124_264306_iw2/PS/
#                                ps_pixels.tif
# ⠙ 245/410 Processing (512, 512) sized blocks... ━━━━━━━━━━━╺━━━━━━━  60% 0:00:14

# %% [markdown]
# ## 4. Visualize the IFG and UNW data

# %%
# Get reference and secondary dates
ref = referenceDate.strftime('%Y%m%d')
sec = secondaryDate.strftime('%Y%m%d')

print(f'Reference Date: {ref}')
print(f'Secondary Date: {sec}')

# Read the merged wrapped file
src = rioxarray.open_rasterio(f'./interferograms/{ref}_{sec}.int')
src = src.rio.reproject("EPSG:4326")[0]         # Reproject coordinates to EPSG:4326
minlon,minlat,maxlon,maxlat = src.rio.bounds()
merged_ifg = np.angle(src)
merged_ifg[merged_ifg==0] = np.nan              # Mask zero values
src = []

# %%
# Define bounding box
bbox = [minlon,maxlon,minlat,maxlat]

# Plot using Matplotlib
fig, ax = plt.subplots(figsize=[12,9])
cax = ax.imshow(merged_ifg, cmap='jet',interpolation='nearest', origin='upper',extent=bbox)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title(f'WRP_{ref}-{sec}_{orbitPass[0]}{pathNumber}',fontsize=12)
cbar = fig.colorbar(cax,orientation='vertical',fraction=0.01,pad=0.02)
cbar.set_ticks([-np.pi, 0., np.pi])
cbar.set_ticklabels([r'$-\pi$', '$0$', r'$\pi$'])
plt.show()

# %%
## Set Reference Points
xsize = 0.000277778; ysize = -0.000277778           # Assuming 30-m resolution
refx = 2642; refy = 2700;
reflon = minlon + (refx * xsize)
reflat = maxlat + (refy * ysize)

# %%
# Read the unwrapped file
src = rioxarray.open_rasterio(f'./unwrapped/{ref}_{sec}.unw.tif')
merged_unw = src.rio.reproject("EPSG:4326")[0] * wavelength / (-4 * np.pi)
src = []

# Plot using Matplotlib
fig, ax = plt.subplots(figsize=[12,9])
merged_unw_cm = merged_unw*100
merged_unw_cm -= merged_unw_cm[refy, refx]              # Reference the data to a point
cax = ax.imshow(merged_unw_cm, cmap='RdBu_r',interpolation='nearest', origin='upper', extent=bbox, vmin=np.min(merged_unw_cm), vmax=-np.min(merged_unw_cm))
ax.plot(reflon, reflat, 'ks')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title(f'UNW_{ref}-{sec}_{orbitPass[0]}{pathNumber}',fontsize=12)
cbar = fig.colorbar(cax,orientation='vertical',fraction=0.01,pad=0.02)
cbar.set_label('LOS Displacement (cm)', rotation=270, labelpad=15)
plt.show()

# %%
# Delete temporary "cslc" folder to save storage space
# !rm -rvf ./cslc
