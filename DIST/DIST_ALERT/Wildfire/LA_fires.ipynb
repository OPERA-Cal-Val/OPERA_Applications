# %% [markdown]
# # Quantifying Wildfire Impacts Using the OPERA DIST-HLS Product
#
# ### Example below showcases a wildfire event that impacted multiple regions of the greater Los Angeles, California area (01/07/2025-Ongoing).

# %% [markdown]
# The Leafmap library provides a suite of tools for interactive mapping and visualization in Jupyter Notebooks Leafmap version 0.30.0 and and later offer tools specifically for accessing NASA Earthdata by building on the newly developed NASA Earthaccess library. Earthaccess provides streamlined access to NASA Earthdata and simplifies the authentication and querying process over previously developed approaches.This notebook is designed to leverage tools within Earthaccess and Leafmap to facility easier access and vizualization of OPERA data products for a user-specified area of interest (AOI).

# %% [markdown]
# ## OPERA DIST-ALERT-HLS info
# See website https://www.jpl.nasa.gov/go/opera/products/dist-product-suite/

# %% [markdown]
# ## Import Libraries
# Ensure that following dependencies are installed into you environement. This notebook was developed using the `opera_app` environment, which can be found in the [OPERA Applications Github repository](https://github.com/OPERA-Cal-Val/OPERA_Applications).

# %%
from datetime import datetime
import numpy as np
import leafmap
import os
import pandas as pd
import rasterio
import shutil

# %%
### Set working directory (modify to your desired path)
working_directory = '/LA_fires'
os.makedirs(working_directory, exist_ok=True)
os.chdir(working_directory)

# Verify the working directory
print("Current working directory:", os.getcwd())

# %% [markdown]
# ## Authentication
# A [NASA Earthdata Login](https://urs.earthdata.nasa.gov/) account is required to download the data used in this tutorial. You can create an account at the link provided. After establishing an account, the code in the next cell will verify authentication. If this is your first time running the notebook, you will be prompted to enter your Earthdata login credentials, which will be saved in ~/.netrc.

# %%
leafmap.nasa_data_login()

# %% [markdown]
# ## View NASA Earthdata datasets
# A tab separated values (TSV) file, made available through the opengeos Github repository, catalogues metadata for more than 9,000 datasets available through NASA Earthdata. In the next cell we load the TSV into a pandas dataframe and view the metadata for the first five (5) Earthdata products

# %%
### View Earthdata datasets
earthdata_url = 'https://github.com/opengeos/NASA-Earth-Data/raw/main/nasa_earth_data.tsv'
earthdata_df = pd.read_csv(earthdata_url, sep='\t')
# earthdata_df.head()

# %% [markdown]
# ## View the available OPERA products
# Note above that the `earthdata_df` contains a number of columns with metadata about each available product. the `ShortName` column will be used to produce a new dataframe containing only OPERA products. Let's view the available products and their metadata.

# %%
opera_df = earthdata_df[earthdata_df['ShortName'].str.contains('OPERA', case=False)]

# %% [markdown]
# ## Define an area of interest (AOI) and time period of interest (TOI)
# Define an area of interest (AOI) for the wildfire event.

# %%
### This cell initializes the AOI and TOI.
AOI = (-120.019, 33.528, -116.219, 34.540) #W, S, E, N; Los Angeles, CA, USA

StartDate_PostFire="2025-1-11T00:00:00"  #Post-fire image start date
EndDate_PostFire="2025-1-14T23:59:59"    #Post-fire image end date

# %% [markdown]
# ## Query Earthdata and return metadata for OPERA products within the AOI
# The `earthaccess` library makes it simple to quickly query NASA's Common Metadata Repository (CMR) and return the associated metadata as a Geodataframe. `Leafmap` has recently added functionality that builds on `earthaccess` to enable interactive viewing of this data.
# In the next cell, the user should specify which OPERA product and the date range of interest. The AOI defined previously is used as the boundary in the query.

# %% [markdown]
# ### View OPERA Product Shortnames

# %%
### Print the available OPERA datasets 
print('Available OPERA datasets:', opera_df['ShortName'].values)
# Out:
# Available OPERA datasets: ['OPERA_L2_CSLC-S1-STATIC_V1' 'OPERA_L2_CSLC-S1_V1'
#  'OPERA_L2_RTC-S1-STATIC_V1' 'OPERA_L2_RTC-S1_V1'
#  'OPERA_L3_DIST-ALERT-HLS_V1' 'OPERA_L3_DIST-ANN-HLS_V1'
#  'OPERA_L3_DSWX-HLS_V1']

# %% [markdown]
# ### Query the OPERA DIST-ALERT-HLS dataset for the AOI

# %%
dist_results_PostFire, dist_gdf_PostFire = leafmap.nasa_data_search(
    short_name='OPERA_L3_DIST-ALERT-HLS_V1',
    cloud_hosted=True,
    bounding_box= AOI,
    temporal=(StartDate_PostFire, EndDate_PostFire),
    count=-1,  # use -1 to return all datasets
    return_gdf=True,
)
# Out:
# Granules found: 8

# %% [markdown]
# ### See the available DSWx-HLS layers
# Functionality within earthaccess enables more more asthetic views of the available layers, as well as displaying the thumbnail. These links are clickable and will download in the browser when clicked.

# %%
dist_results_PostFire[0] #Note this just shows a single MGRS/HLS tile
# Out:
# Collection: {'ShortName': 'OPERA_L3_DIST-ALERT-HLS_V1', 'Version': '1'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -116.19741269, 'Latitude': 34.25029435}, {'Longitude': -115.88645427, 'Latitude': 35.23795494}, {'Longitude': -117.00021983, 'Latitude': 35.24307771}, {'Longitude': -117.00021722, 'Latitude': 34.25292159}, {'Longitude': -116.19741269, 'Latitude': 34.25029435}]}}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2025-01-12T18:44:38.298640Z', 'EndingDateTime': '2025-01-12T18:44:38.298640Z'}}
# Size(MB): 0
# Data: ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-IND.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-HIST.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-CONF.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DATE.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-COUNT.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DUR.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-LAST-DATE.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-CONF.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DATE.tif', 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ALERT-HLS_V1/OPERA_L3_DIST-ALERT-HL ...

# %% [markdown]
# ### View the DIST-ALERT-HLS metadata and footprints

# %%
dist_gdf_PostFire.head()
# Out:
#    size concept-type           concept-id  revision-id  \
# 0     0      granule  G3369013897-LPCLOUD            1
# 1     0      granule  G3369013507-LPCLOUD            1
# 2     0      granule  G3369253276-LPCLOUD            1
# 3     0      granule  G3368946588-LPCLOUD            1
# 4     0      granule  G3369087011-LPCLOUD            1
#
#                                            native-id collection-concept-id  \
# 0  OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731...   C2746980408-LPCLOUD
# 1  OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731...   C2746980408-LPCLOUD
# 2  OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731...   C2746980408-LPCLOUD
# 3  OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731...   C2746980408-LPCLOUD
# 4  OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731...   C2746980408-LPCLOUD
#
#   provider-id                             format             revision-date  \
# 0     LPCLOUD  application/vnd.nasa.cmr.umm+json  2025-01-14T04:23:10.829Z
# 1     LPCLOUD  application/vnd.nasa.cmr.umm+json  2025-01-14T04:22:15.864Z
# 2     LPCLOUD  application/vnd.nasa.cmr.umm+json  2025-01-14T10:48:04.412Z
# 3     LPCLOUD  application/vnd.nasa.cmr.umm+json  2025-01-14T02:22:56.583Z
# 4     LPCLOUD  application/vnd.nasa.cmr.umm+json  2025-01-14T06:44:20.103Z
#
#              BeginningDateTime  ...  \
# 0  2025-01-12T18:44:38.298640Z  ...
# 1  2025-01-12T18:44:42.413250Z  ...
# 2  2025-01-12T18:44:45.870830Z  ...
# 3  2025-01-12T18:44:49.968680Z  ...
# 4  2025-01-12T18:44:52.934960Z  ...
#
#                                        ProviderDates  \
# 0  [{'Date': '2025-01-14T04:21:04.126105Z', 'Type...
# 1  [{'Date': '2025-01-14T04:19:51.087400Z', 'Type...
# 2  [{'Date': '2025-01-14T10:46:34.548313Z', 'Type...
# 3  [{'Date': '2025-01-14T02:09:17.300882Z', 'Type...
# 4  [{'Date': '2025-01-14T06:41:24.402520Z', 'Type...
#
#                     ShortName  \
# 0  OPERA_L3_DIST-ALERT-HLS_V1
# 1  OPERA_L3_DIST-ALERT-HLS_V1
# 2  OPERA_L3_DIST-ALERT-HLS_V1
# 3  OPERA_L3_DIST-ALERT-HLS_V1
# 4  OPERA_L3_DIST-ALERT-HLS_V1
#
#                                          RelatedUrls CloudCover DayNightFlag  \
# 0  [{'URL': 'https://data.lpdaac.earthdatacloud.n...          1          Day
# 1  [{'URL': 'https://data.lpdaac.earthdatacloud.n...          2          Day
# 2  [{'URL': 'https://data.lpdaac.earthdatacloud.n...          1          Day
# 3  [{'URL': 'https://data.lpdaac.earthdatacloud.n...          2          Day
# 4  [{'URL': 'https://data.lpdaac.earthdatacloud.n...          8          Day
#
#             ProductionDateTime  \
# 0  2025-01-14T04:21:04.126105Z
# 1  2025-01-14T04:19:51.087400Z
# 2  2025-01-14T10:46:34.548313Z
# 3  2025-01-14T02:09:17.300882Z
# 4  2025-01-14T06:41:24.402520Z
#
#                                            Platforms  \
# 0  [{'ShortName': 'Sentinel-2A', 'Instruments': [...
# 1  [{'ShortName': 'Sentinel-2A', 'Instruments': [...
# 2  [{'ShortName': 'Sentinel-2A', 'Instruments': [...
# 3  [{'ShortName': 'Sentinel-2A', 'Instruments': [...
# 4  [{'ShortName': 'Sentinel-2A', 'Instruments': [...
#
#                                                  URL   Name  \
# 0  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
# 1  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
# 2  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
# 3  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
# 4  https://cdn.earthdata.nasa.gov/umm/granule/v1.6.6  UMM-G
#
#                                             geometry
# 0  POLYGON ((-116.19741 34.25029, -115.88645 35.2...
# 1  POLYGON ((-118.08644 34.24811, -116.89400 34.2...
# 2  POLYGON ((-119.17150 34.23369, -117.97959 34.2...
# 3  POLYGON ((-119.48721 34.22769, -119.06537 34.2...
# 4  POLYGON ((-116.47563 33.35025, -116.16983 34.3...
#
# [5 rows x 24 columns]

# %%
### Plot the location of the tiles 
dist_gdf_PostFire.explore(fill=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ca1abf925ed42bb5f1535d1bf9bb66f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ca1abf925ed42bb5f1535d1bf9bb66f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ca1abf925ed42bb5f1535d1bf9bb66f = L.map(
#                 &quot;map_0ca1abf925ed42bb5f1535d1bf9bb66f&quot;,
#                 {
#                     center: [34.282200599999996, -117.80878975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0ca1abf925ed42bb5f1535d1bf9bb66f);
#
#
#
#
#
#             var tile_layer_bdfe6159df040c2526a0210656c37f8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bdfe6159df040c2526a0210656c37f8f.addTo(map_0ca1abf925ed42bb5f1535d1bf9bb66f);
#
#
#             map_0ca1abf925ed42bb5f1535d1bf9bb66f.fitBounds(
#                 [[33.32132349, -119.73112523], [35.24307771, -115.88645427]],
#                 {}
#             );
#
#
#         function geo_json_82b3b9bf2924956f525503f44ac30899_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_82b3b9bf2924956f525503f44ac30899_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_82b3b9bf2924956f525503f44ac30899_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_82b3b9bf2924956f525503f44ac30899_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_82b3b9bf2924956f525503f44ac30899_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_82b3b9bf2924956f525503f44ac30899.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_82b3b9bf2924956f525503f44ac30899_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_82b3b9bf2924956f525503f44ac30899 = L.geoJson(null, {
#                 onEachFeature: geo_json_82b3b9bf2924956f525503f44ac30899_onEachFeature,
#
#                 style: geo_json_82b3b9bf2924956f525503f44ac30899_styler,
#                 pointToLayer: geo_json_82b3b9bf2924956f525503f44ac30899_pointToLayer,
#                 fill: false,
#         });
#
#         function geo_json_82b3b9bf2924956f525503f44ac30899_add (data) {
#             geo_json_82b3b9bf2924956f525503f44ac30899
#                 .addData(data);
#         }
#             geo_json_82b3b9bf2924956f525503f44ac30899_add({&quot;bbox&quot;: [-119.73112523, 33.32132349, -115.88645427, 35.24307771], &quot;features&quot;: [{&quot;bbox&quot;: [-117.00021983, 34.25029435, -115.88645427, 35.24307771], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-116.19741269, 34.25029435], [-115.88645427, 35.23795494], [-117.00021983, 35.24307771], [-117.00021722, 34.25292159], [-116.19741269, 34.25029435]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AdditionalAttributes&quot;: [{&quot;Name&quot;: &quot;Input_DIST-ALERT_granule&quot;, &quot;Values&quot;: [&quot;OPERA_L3_DIST-ALERT-HLS_T11SNU_20250109T182731Z_20250111T105617Z_S2A_30_v1&quot;]}, {&quot;Name&quot;: &quot;BaselineCalendarWindow&quot;, &quot;Values&quot;: [

# %%
dist_gdf_PostFire['geometry'].to_file('DIST-HLS_LA_Fires.geojson',driver='GeoJSON')

# %% [markdown]
# ## Download data with leafmap
# Let's download the data from one of our above queries. In the cell below we specify data from the DIST-ALERT-HLS.

# %% [markdown]
# ### Create a subdirectory
# This will be where the files are downloaded. It will be a subdirectory inside of a directory called `data`, and the directory name will be the date that it was created.

# %%
def create_data_directory():
    current_datetime = datetime.now().strftime("%m_%d_%Y")

    # Define the base directory
    base_directory = "data"

    # Create the full path for the new directory
    new_directory_path_PostFire = os.path.join(base_directory, f"data_{current_datetime}")
    # Create the new directory
    os.makedirs(new_directory_path_PostFire, exist_ok=True)

    print(f"Directory '{new_directory_path_PostFire}' created successfully.")

    return new_directory_path_PostFire

directory_path_PostFire = create_data_directory()
# Out:
# Directory 'data/data_01_14_2025' created successfully.

# %% [markdown]
# ### Download the data
# The below will download the data to your newly created subdirectory. Look on your file system for a directory `/data/date/` where `date` is the date the directory was created.

# %%
dist_data_PostFire = leafmap.nasa_data_download(dist_results_PostFire, out_dir=directory_path_PostFire)
# Out:
#  Getting 8 granules, approx download size: 0.0 GB
# QUEUEING TASKS | :   0%|          | 0/152 [00:00<?, ?it/s]
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-IND.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-HIST.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_DATA-MASK.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-IND.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-HIST.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_DATA-MASK.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-IND.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-HIST.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_DATA-MASK.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-IND.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-HIST.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_DATA-MASK.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-HIST.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-IND.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_DATA-MASK.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-IND.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-HIST.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_DATA-MASK.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-IND.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-HIST.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_DATA-MASK.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-IND.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-HIST.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-ANOM.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-COUNT.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-STATUS.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-CONF.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-ANOM-MAX.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-LAST-DATE.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DUR.tif already downloaded
# File OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_DATA-MASK.tif already downloaded
# PROCESSING TASKS | :   0%|          | 0/152 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/152 [00:00<?, ?it/s]

# %% [markdown]
# ### Filter to post-event disturbance
# We would like to view only disturbance detected after the LA wildfires. To do so, we produce a 'filtered' derivative of the DIST-ALERT-HLS layers based on the date of intitial disturbance detection (from the VEG-DIST-DATE layer). Pixel values in the VEG-DIST-DATE layer correspond the date of initial disturbance detection in days since December 31, 2020. Because the wildfire began 7 January 2025, we filter out disturbance that occurred before this date, corresponding to VEG-DIST-DATE pixel values less than 1467 (the number of since 12/31/2020).
#
# Below we calculate the number of days since December 31, 2020 and store it as a variable, which will be used as input in a subsequent step.

# %%
# Define the reference date and the target date
reference_date = datetime(2020, 12, 31)
target_date = datetime(2025, 1, 6)

# Calculate the difference between the two dates
delta = target_date - reference_date

# Get the number of days from the timedelta object
days_since_reference = delta.days

print("Number of days:", days_since_reference)
# Out:
# Number of days: 1467

# %% [markdown]
# For this exercise, we are only interested in disturbance detected after the wildfire began on 01/07/2025. Below, we compute a new set of raster layers that are filtered to contain only data following date of interest (day 1467, in this case).

# %%
# Initialize a dictionary to store unique IDs and their corresponding file names
layers_dict = {}

# Iterate over files in the directory
for filename in os.listdir(directory_path_PostFire):
    # Check if the filename matches the expected format
    if filename.endswith('.tif'):
        # Split the filename by underscores
        parts = filename.split('_')
        
        # Ensure there are enough parts to avoid index errors
        if len(parts) >= 5:
            # Extract the unique ID (assuming it’s at index 3)
            unique_id = parts[3]  # Adjust the index if needed
            
            # Add the full filename to the dictionary under the corresponding unique ID
            if unique_id not in layers_dict:
                layers_dict[unique_id] = []  # Initialize an empty list if ID not in dictionary
            
            layers_dict[unique_id].append(filename)

# Print the dictionary of unique IDs and their associated file names
print("Dictionary of unique IDs and corresponding files:")
for unique_id, files in layers_dict.items():
    print(f"{unique_id}: {files}")
# Out:
# Dictionary of unique IDs and corresponding files:
# T11SKU: ['OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-HIST.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_DATA-MASK.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-IND.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-ANOM.tif']
# T11SNT: ['OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_DATA-MASK.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-HIST.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-IND.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-LAST-DATE.tif']
# T11SLU: ['OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-IND.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_DATA-MASK.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-HIST.tif']
# T11SLT: ['OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_DATA-MASK.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-IND.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-HIST.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-ANOM.tif']
# T11SKT: ['OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-HIST.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-IND.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_DATA-MASK.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-COUNT.tif']
# T11SMT: ['OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_DATA-MASK.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-HIST.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-IND.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-CONF.tif']
# T11SNU: ['OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_DATA-MASK.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-IND.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-HIST.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-CONF.tif']
# T11SMU: ['OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_DATA-MASK.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-ANOM-MAX.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-IND.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-DUR.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-STATUS.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-LAST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-COUNT.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-ANOM.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-DATE.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-CONF.tif', 'OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-HIST.tif']

# %%
# Function to generate filtered rasters
def generate_filtered_rasters(layers_dict, threshold, output_subdir='filtered'):
    # Ensure the output subdirectory exists
    output_dir = os.path.join(directory_path_PostFire, output_subdir)
    os.makedirs(output_dir, exist_ok=True)

    # Process each unique_id
    for unique_id, file_list in layers_dict.items():
        # Identify the reference _VEG-DIST-DATE.tif file
        date_file = next((f for f in file_list if f.endswith('_VEG-DIST-DATE.tif')), None)
        if not date_file:
            print(f"Warning: No '_VEG-DIST-DATE.tif' file found for {unique_id}")
            continue

        # Open the _VEG-DIST-DATE.tif file and create a mask based on the threshold
        date_file_path = os.path.join(directory_path_PostFire, date_file)
        with rasterio.open(date_file_path) as src:
            date_data = src.read(1)  # Read the first (and only) band
            date_mask = date_data >= threshold  # Mask where date data exceeds the threshold

        # Apply the mask to each layer file
        for file in file_list:
            # If the file is _VEG-DIST-DATE.tif, apply the threshold and save a filtered version
            if file == date_file:
                with rasterio.open(date_file_path) as src:
                    date_filtered_data = np.where(date_mask, date_data, src.nodata)  # Apply the mask
                    date_filtered_filename = file.replace('.tif', '_filtered.tif')  # Update filename
                    date_filtered_path = os.path.join(output_dir, date_filtered_filename)
                    
                    # Save the filtered _VEG-DIST-DATE.tif raster
                    src_meta = src.meta
                    src_meta.update({"nodata": src.nodata})
                    with rasterio.open(date_filtered_path, 'w', **src_meta) as dest:
                        dest.write(date_filtered_data, 1)  # Write to the first band

                print(f"Generated filtered file: {date_filtered_filename}")
                continue  # Move to the next file in the list

            # If file is _DATA-MASK.tif, copy it directly to the output directory with "_filtered" added
            if file.endswith('_DATA-MASK.tif'):
                data_mask_filtered_filename = file.replace('.tif', '_filtered.tif')
                data_mask_filtered_path = os.path.join(output_dir, data_mask_filtered_filename)
                shutil.copy(os.path.join(directory_path_PostFire, file), data_mask_filtered_path)
                
                print(f"Copied _DATA-MASK file: {data_mask_filtered_filename}")
                continue  # Move to the next file in the list

            else:
                print(f"Processing file: {file}")
                # Open the layer file
                file_path = os.path.join(directory_path_PostFire, file)
                with rasterio.open(file_path) as src:
                    layer_data = src.read(1)  # Read the first band
                    layer_meta = src.meta  # Metadata to use for the output file
                    layer_nodata = src.nodata  # Get the 'nan' value for this layer

                    # Apply the mask: where date_mask is False, set layer_data to layer_nodata
                    filtered_data = np.where(date_mask, layer_data, layer_nodata)

                    # Update the filename to include "_filtered"
                    filtered_filename = file.replace('.tif', '_filtered.tif')
                    filtered_file_path = os.path.join(output_dir, filtered_filename)

                    # Save the filtered raster with the same metadata
                    layer_meta.update({"nodata": layer_nodata})
                    with rasterio.open(filtered_file_path, 'w', **layer_meta) as dest:
                        dest.write(filtered_data, 1)  # Write to the first band
                print(f"Generated filtered file: {filtered_filename}")

# Call the function using the 'days_since_reference' variable as the threshold
generate_filtered_rasters(layers_dict, days_since_reference)
# Out:
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-HIST.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-HIST_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-DATE_filtered.tif
# Copied _DATA-MASK file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_DATA-MASK_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-STATUS_filtered.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-IND.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-IND_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-STATUS_filtered.tif
# Copied _DATA-MASK file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_DATA-MASK_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-DUR_filtered.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-HIST.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-HIST_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-IND.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-IND_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-IND.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-IND_filtered.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-CONF_filtered.tif
# Copied _DATA-MASK file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_DATA-MASK_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-HIST.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-HIST_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM_filtered.tif
# Copied _DATA-MASK file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_DATA-MASK_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-IND.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-IND_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-HIST.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-HIST_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-ANOM-MAX_filtered.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_GEN-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-HIST.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-HIST_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-IND.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-IND_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-CONF_filtered.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-DATE_filtered.tif
# Copied _DATA-MASK file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_DATA-MASK_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-STATUS_filtered.tif
# Copied _DATA-MASK file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_DATA-MASK_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-HIST.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-HIST_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-IND.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-IND_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-COUNT_filtered.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_VEG-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMT_20250112T183731Z_20250114T042005Z_S2A_30_v1_GEN-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM-MAX_filtered.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM-MAX_filtered.tif
# Copied _DATA-MASK file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_DATA-MASK_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-IND.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-IND_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-HIST.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-HIST_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-DATE_filtered.tif
# Copied _DATA-MASK file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_DATA-MASK_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-ANOM_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-ANOM-MAX_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-IND.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-IND_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-DUR.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-DUR_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-STATUS_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-LAST-DATE.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-LAST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-COUNT_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-ANOM.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-ANOM_filtered.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-DATE_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-CONF.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_GEN-DIST-CONF_filtered.tif
# Processing file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-HIST.tif
# Generated filtered file: OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-HIST_filtered.tif

# %% [markdown]
# ## Merge filtered rasters
# Below we produce a mosaicked version of each layer, which are saved in a new directory called `merged`

# %%
import os
import rasterio
from rasterio.merge import merge

def merge_filtered_rasters(filtered_rasters_dir):
    
    # Create a directory for merged rasters
    merged_dir = os.path.join(filtered_rasters_dir, 'merged')
    os.makedirs(merged_dir, exist_ok=True)
    
    # Dictionary to hold lists of filenames for each layer
    layer_dict = {}

    # Iterate through filtered rasters to populate the dictionary
    for filename in os.listdir(filtered_rasters_dir):
        if filename.endswith('_filtered.tif'):
            # Split the filename to extract the layer name
            parts = filename.split('_')
            if len(parts) >= 6:  # Check if there are enough parts to avoid index errors
                layer_name = parts[-2]  # Extract the layer name (second-to-last part)
            if layer_name not in layer_dict:
                layer_dict[layer_name] = []
            layer_dict[layer_name].append(os.path.join(filtered_rasters_dir, filename))

    # Merge rasters for each layer and save them
    for layer_name, files in layer_dict.items():
        # Open the rasters and extract nodata values
        src_files_to_mosaic = [rasterio.open(f) for f in files]
        
        # Get the consistent nodata value for the layer
        nodata_value = src_files_to_mosaic[0].nodata
        
        # Perform the merge with preference for data pixels
        mosaic, out_trans = merge(src_files_to_mosaic, nodata=nodata_value, method='first')
        
        # Create metadata for the merged raster
        out_meta = src_files_to_mosaic[0].meta.copy()
        out_meta.update({
            "driver": "GTiff",
            "height": mosaic.shape[1],
            "width": mosaic.shape[2],
            "transform": out_trans,
            "nodata": nodata_value
        })

        # Save the merged raster
        merged_filename = f"{layer_name}_merged.tif"
        merged_filepath = os.path.join(merged_dir, merged_filename)

        with rasterio.open(merged_filepath, 'w', **out_meta) as dest:
            dest.write(mosaic)

        print(f"Merged raster saved as: {merged_filename}")

        # Close all opened raster files
        for src in src_files_to_mosaic:
            src.close()

    return layer_dict

# Call the function with the filtered_rasters directory
filtered_rasters_dir = os.path.join(directory_path_PostFire, 'filtered')
layer_dict = merge_filtered_rasters(filtered_rasters_dir)
# Out:
# Merged raster saved as: GEN-DIST-STATUS_merged.tif
# Merged raster saved as: VEG-IND_merged.tif
# Merged raster saved as: DATA-MASK_merged.tif
# Merged raster saved as: VEG-ANOM-MAX_merged.tif
# Merged raster saved as: VEG-DIST-STATUS_merged.tif
# Merged raster saved as: VEG-DIST-DATE_merged.tif
# Merged raster saved as: VEG-LAST-DATE_merged.tif
# Merged raster saved as: GEN-ANOM_merged.tif
# Merged raster saved as: VEG-ANOM_merged.tif
# Merged raster saved as: GEN-DIST-CONF_merged.tif
# Merged raster saved as: VEG-DIST-COUNT_merged.tif
# Merged raster saved as: GEN-ANOM-MAX_merged.tif
# Merged raster saved as: GEN-LAST-DATE_merged.tif
# Merged raster saved as: VEG-DIST-CONF_merged.tif
# Merged raster saved as: VEG-HIST_merged.tif
# Merged raster saved as: GEN-DIST-DATE_merged.tif
# Merged raster saved as: GEN-DIST-COUNT_merged.tif
# Merged raster saved as: GEN-DIST-DUR_merged.tif
# Merged raster saved as: VEG-DIST-DUR_merged.tif

# %% [markdown]
# ### Add symbology to tiffs
# Some of the DIST-ALERT-HLS layers have embedded symbology. Below we add this symbology to the merged raster layers. If they do not have embedded symbology, they are skipped.

# %%
def add_symbology(merged_raster_path, reference_symbology_path):
    try:
        # Read the reference symbology raster
        with rasterio.open(reference_symbology_path) as src:
            # Check if the symbology raster has a colormap
            if 1 in src.colormap(1):
                src_colormap = src.colormap(1)  # Assuming symbology is in band 1
            else:
                print(f"No colormap found for {reference_symbology_path}")
                return  # Exit if no colormap exists

        # Open the merged raster in write mode
        with rasterio.open(merged_raster_path, 'r+') as dst:
            # Write the color map to the first band
            dst.write_colormap(1, src_colormap)

    except Exception as e:
        print(f"Symbology not present for {reference_symbology_path}: {e}...skipping")

symbology_layers = {}

# Loop over each layer in the layer_dict
for layer in layer_dict:
    # Check if we already found a file for this layer
    if layer not in symbology_layers:
        # Loop over each file in the directory
        for filename in os.listdir(directory_path_PostFire):
            # Check if the file is a .tif file
            if filename.endswith('.tif'):
                # Extract the layer name (last part before the extension)
                layer_name = filename.split('_')[-1].split('.')[0]
                
                # Check if the layer name matches the current layer
                if layer_name == layer:
                    # Save the full file path for the first match
                    symbology_layers[layer] = os.path.join(directory_path_PostFire, filename)
                    break  # Stop once the first file for this layer is found

# Print the found file paths for each layer
for layer, path in symbology_layers.items():
    print(f"Layer {layer}: {path}")

# Apply symbology to each merged raster
for layer in layer_dict:
    merged_path = os.path.join(filtered_rasters_dir, 'merged', f"{layer}_merged.tif")
    symbology_path = symbology_layers.get(layer)
    if symbology_path:
        add_symbology(merged_path, symbology_path)
    else:
        print(f"No symbology file found for layer: {layer}")
# Out:
# Layer GEN-DIST-STATUS: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-STATUS.tif
# Layer VEG-IND: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-IND.tif
# Layer DATA-MASK: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_DATA-MASK.tif
# Layer VEG-ANOM-MAX: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM-MAX.tif
# Layer VEG-DIST-STATUS: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-DIST-STATUS.tif
# Layer VEG-DIST-DATE: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DATE.tif
# Layer VEG-LAST-DATE: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-LAST-DATE.tif
# Layer GEN-ANOM: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM.tif
# Layer VEG-ANOM: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM.tif
# Layer GEN-DIST-CONF: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-CONF.tif
# Layer VEG-DIST-COUNT: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-COUNT.tif
# Layer GEN-ANOM-MAX: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM-MAX.tif
# Layer GEN-LAST-DATE: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-LAST-DATE.tif
# Layer VEG-DIST-CONF: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-CONF.tif
# Layer VEG-HIST: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-HIST.tif
# Layer GEN-DIST-DATE: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DATE.tif
# Layer GEN-DIST-COUNT: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-COUNT.tif
# Layer GEN-DIST-DUR: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DUR.tif
# Layer VEG-DIST-DUR: data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DUR.tif
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SMU_20250112T183731Z_20250114T041951Z_S2A_30_v1_VEG-IND.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_DATA-MASK.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-ANOM-MAX.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_VEG-DIST-DATE.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-LAST-DATE.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SLT_20250112T183731Z_20250114T041808Z_S2A_30_v1_VEG-ANOM.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-DIST-CONF.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_VEG-DIST-COUNT.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_GEN-ANOM-MAX.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNU_20250112T183731Z_20250114T042104Z_S2A_30_v1_GEN-LAST-DATE.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_VEG-DIST-CONF.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKU_20250112T183731Z_20250114T020917Z_S2A_30_v1_VEG-HIST.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SKT_20250112T183731Z_20250114T020658Z_S2A_30_v1_GEN-DIST-DATE.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SNT_20250112T183731Z_20250114T064124Z_S2A_30_v1_GEN-DIST-COUNT.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_GEN-DIST-DUR.tif: NULL color table...skipping
# Symbology not present for data/data_01_14_2025/OPERA_L3_DIST-ALERT-HLS_T11SLU_20250112T183731Z_20250114T104634Z_S2A_30_v1_VEG-DIST-DUR.tif: NULL color table...skipping

# %% [markdown]
# ## View the files using Leafmap
# We can visualize a few of the layers using the `leafmap` library. After the map renders, click the upper right corner to toggle on/off the layers.

# %%
import leafmap

# Initialize a Leafmap map
m = leafmap.Map(center=[40, -100], zoom=4)

# Visualize a few of the layers
layers_viz = ['VEG-DIST-STATUS', 'VEG-ANOM-MAX', 'VEG-DIST-DATE']

# Loop over each layer in layer_dict and add the corresponding merged raster to the map
for layer in layers_viz:
    merged_path = os.path.join(filtered_rasters_dir, 'merged', f"{layer}_merged.tif")
    
    # Check if the merged raster file exists
    if os.path.exists(merged_path):
        # Add the raster to the map with a label
        m.add_raster(merged_path, layer_name=layer, opacity=0.6)

# Display the map
m
# Out:
# Map(center=[34.276311, -118.04433850000001], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_…
