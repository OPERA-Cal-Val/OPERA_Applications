# %% [markdown]
# # Visualizing and Analyzing the OPERA DIST-ANN-HLS Product to Visualize Wildfire Impact in Northern Quebec
# This notebook is designed to showcase the use of the OPERA `DIST-ANN-HLS` product to visualize and quantify vegetation disturbance associated with a series of wildfires that affected northern Quebec during the 2023 calendar year.
#
# The OPERA `DIST-ANN-HLS` represents a yearly summary of confirmed vegetagion disturbances flagged by the OPERA `DIST-ALERT-HLS` product. To explore use cases of the OPERA `DIST-ALERT-HLS` product, see our example notebooks on [wildfire impacts](https://github.com/OPERA-Cal-Val/OPERA_Applications/blob/main/DIST/DIST_ALERT/Wildfire/McKinney.ipynb) and [flooding and landslides](https://github.com/OPERA-Cal-Val/OPERA_Applications/blob/main/DIST/DIST_ALERT/Flood_and_Landslide/NorthCarolina_Helene_Flood_Landslides_Sept2024.ipynb).
#
# A [NASA Earthdata](https://earthdata.nasa.gov/) account is required to download the data used in this tutorial. You can create an account [here](https://earthdata.nasa.gov/data/earthdata-login). These credentials must be stored in a `.netrc` file on your local filesystem.
#
# *<font color='red'>Note 1: Please refer to [DIST product specification](https://lpdaac.usgs.gov/documents/1766/OPERA_DIST_HLS_Product_Specification_V1.pdf) for more information. </font>*<br>
# *<font color='red'>Note 2: DIST products are distributed via NASA's Distributed Active Archive Centers (DAACs), specifically the [LP DAAC](https://lpdaac.usgs.gov).</font>*

# %% [markdown]
# ## Background
# A series of wildfires affected northern Quebec, Canada during the summer of 2023. We will be exploring the OPERA `DIST-ANN-HLS` product to analyze vegetation disturbance associated with a subset of these fires located near Lac Guéguen, La Vallée-de-l'Or, Quebec.
#
# *For more information about the fires that affected Quebec during 2023, please see the [Natural Resources of Canada Website](https://natural-resources.canada.ca/stories/simply-science/canada-s-record-breaking-wildfires-2023-fiery-wake-call)*
#
# ### The OPERA `DIST-HLS` Product Suite
# ---
# The OPERA Land Surface Disturbance from Harmonized Landsat and Sentinel-2 (`DIST-HLS`) product suite maps vegetation disturbance using surface reflectance data from Harmonized Landsat and Sentinel-2 (`HLS`). Disturbance is identified when vegetation cover declines or spectral variation falls outside the historical norm for a given `HLS` pixel.
#
# The suite includes two complementary products:
#
# - **`DIST-ALERT-HLS`**: Detects vegetation disturbance at the native `HLS` cadence (every 2–3 days).
# - **`DIST-ANN-HLS`**: Summarizes confirmed disturbances from `DIST-ALERT-HLS` over the previous calendar year.
#
# `DIST-ALERT-HLS` is distributed as 19 GeoTIFF layers plus a metadata file, organized in folders corresponding to each input `HLS` tile.
# `DIST-ANN-HLS` includes 21 GeoTIFF layers and a metadata file per tile.
#
# `DIST-HLS` data are projected onto the Military Grid Reference System (MGRS). Each tile spans 109.8 km², consisting of 3,660 x 3,660 pixels at 30-meter resolution, with ~4.9 km of overlap with neighboring tiles.
# Detailed descriptions of the raster layers and their properties are available in the [OPERA DIST-HLS Product Specification Document](https://lpdaac.usgs.gov/documents/1766/OPERA_DIST_HLS_Product_Specification_V1.pdf).
#
# ### HLS Data
# ---
# The Harmonized Landsat and Sentinel-2 (`HLS`) dataset provides surface reflectance (SR) data from two satellite sensors:
#
# - **OLI** (Operational Land Imager) on Landsat-8
# - **MSI** (Multi-Spectral Instrument) on Sentinel-2A and 2B
#
# `HLS` data are projected onto the Military Grid Reference System (MGRS). Each tile spans 109.8 km², consisting of 3,660 x 3,660 pixels at 30-meter resolution, with ~4.9 km of overlap with neighboring tiles.
#
# ### Accessing the Data
# ---
# `DIST-HLS` products are publicly available via NASA’s Distributed Active Archive Centers (DAACs), specifically through the [LP DAAC](https://lpdaac.usgs.gov).

# %% [markdown]
# ## Library Imports, Authentication, and Configuration
# First we import the necessary Python libraries. These come pre-installed in the `opera_app` anaconda environement within the [OPERA Applications Gitub repository](https://github.com/OPERA-Cal-Val/OPERA_Applications). We also import a collection of custom DIST-specific functions from a source file called `dist_utils.py`.

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

import os
import earthaccess
import geopandas as gpd
import ipyleaflet
import leafmap.leafmap as leafmap

import holoviews as hv
hv.extension('bokeh')

import sys
sys.path.append('../../')
from src.dist_utils import *

# %% [markdown]
# ## Authentication with NASA Earthdata credentials
# A [NASA Earthdata Login](https://urs.earthdata.nasa.gov/) account is required to download the data used in this tutorial. You can create an account at the link provided. After establishing an account, the code in the next cell will verify authentication. If this is your first time running the notebook, you will be prompted to enter your Earthdata login credentials, which will be saved in ~/.netrc.

# %%
auth = earthaccess.login(strategy="netrc")
s3_credentials = auth.get_s3_credentials(daac="PODAAC")

# %% [markdown]
# The next cell configures the `gdal` library and provideds necessary authentication to successfully access cloud-hosted assets.

# %%
# Set GDAL configs to successfully access Cloud Assets via vsicurl
gdal.SetConfigOption("GDAL_HTTP_UNSAFESSL", "YES")
gdal.SetConfigOption('GDAL_HTTP_COOKIEFILE','~/cookies.txt')
gdal.SetConfigOption('GDAL_HTTP_COOKIEJAR', '~/cookies.txt')
gdal.SetConfigOption('GDAL_DISABLE_READDIR_ON_OPEN','FALSE')
gdal.SetConfigOption('CPL_VSIL_CURL_ALLOWED_EXTENSIONS','TIF')

# %% [markdown]
# ## Create Products from Harmonized Landsat and Sentinel-2 (HLS) Data
# The OPERA Land Surface Disturbance from Harmonized Landsat and Sentinel-2 (`DIST-HLS`) product suite is derived from Harmonized Landsat and Sentinel-2 (`HLS`) scenes. The time series of `HLS` is what provides the quantification of vegetation disturbance.
#
# In the next cell, we access and download `HLS` data to provide some background and insight into how the `DIST-HLS` product suite is derived. We have chosen an `HLS` tile that covers the fire-affected region. We retreive this tile for two different dates, namely May 11, 2023 (pre-fire) and October 3, 2023 (post-fire). The tiles have the exact same spatial extent. The next cell will use custom functions contained in `dist_utils.py` to produce three `HLS` products: **(1)** True color; **(2)** False color; and **(3)** Normalized Difference Vegetation Index (NDVI). These files will be available in a subdirectory on the user's file system called `tifs`. The false color and NDVI products help to visualize changes in vegetation that are further quantified with the `DIST-HLS` products.

# %%
# Create directory to save outputs
os.makedirs('tifs', exist_ok=True)

# Path to data location on LP DAAC and provide list of desired bands
hls1 = 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUU.2023141T160831.v2.0/HLS.S30.T18UUU.2023141T160831.v2.0.'
hls2 = 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18UUU.2023276T161019.v2.0/HLS.S30.T18UUU.2023276T161019.v2.0.'
bandlist = ['B05','B04','B03','B02']

# Make true color image
make_hls_true_color(hls1, bandlist, 'tifs/true_color_05_11_2023_Quebec.tif')
make_hls_true_color(hls2, bandlist, 'tifs/true_color_10_03_2023_Quebec.tif')

# Make false color image
make_hls_false_color(hls1, bandlist, 'tifs/false_color_05_11_2023_Quebec.tif')
make_hls_false_color(hls2, bandlist, 'tifs/false_color_10_03_2023_Quebec.tif')

# Make ndvi image
make_hls_ndvi(hls1, bandlist, 'tifs/ndvi_05_11_2023_Quebec.tif')
make_hls_ndvi(hls2, bandlist, 'tifs/ndvi_10_03_2023_Quebec.tif')

# %% [markdown]
# ### Open the OPERA DIST-ANN `VEG-DIST-STATUS` layer and write to a local `veg_dist_status.tif`

# %%
veg_dist_status_url = ["https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/OPERA_L3_DIST-ANN-HLS_V1/OPERA_L3_DIST-ANN-HLS_T18UUU_2023_20240216T213139Z_30_v1/OPERA_L3_DIST-ANN-HLS_T18UUU_2023_20240216T213139Z_30_v1_VEG-DIST-STATUS.tif"]
veg_dist_status = earthaccess.open(veg_dist_status_url, provider='LPDAAC')[0]

# Path to save
out_path = os.path.join('tifs', 'veg_dist_status_Quebec.tif')

# Write bytes to file
with open(out_path, 'wb') as f_out:
    # Read the file-like object in chunks to avoid memory issues if large
    chunk_size = 1024 * 1024  # 1MB
    while True:
        chunk = veg_dist_status.read(chunk_size)
        if not chunk:
            break
        f_out.write(chunk)

# %% [markdown]
# ## Visualize Pre- and Post-Fire HLS Products
# We now visualize the true color, false color, and NDVI images for the area of interest. First let's visualize the pre- and post-fire true color `HLS` data. This visualization workflow uses the open-source `leafmap` Python library to create informative timelapse visualizations of the area of interest. `leafmap` provides numerous powerful capabilities for geospatial data visualization and analysis in the Jupyer environment. For additional details on the `leafmap` library, see the [leafmap docs](https://leafmap.org).
#
# Below we create a series of 'split maps' which show the pre-fire image on the left hand side and the post-fire image on the right hand side. The map that appears after executing the cell is interactive. Move the slider to the right to view the May 11, 2023 (pre-fire) image and to the left to view the October 3, 2023 (post-fire) image.

# %%
m = leafmap.Map(center=[48.5, -77], zoom=10)
m.split_map(
    left_layer='tifs/true_color_05_11_2023_Quebec.tif',
    right_layer='tifs/true_color_10_03_2023_Quebec.tif',
    left_label='05-11-2023',
    right_label='10-03-2023'
)
m

# %% [markdown]
# Close examination reveals a difference in the visual appearance of the landscape in the left side of the post-fire true color image. These regions are burn scars associated with the fires. You may notice other areas that appear visually different between the two scenes. However, visually the fire-affected areas are not very easy to delineate in the true color image. We can leverage both the false color and NDVI images to more clearly see the affected region. Let's first look at a false color image of the same area (explained further below).

# %%
m = leafmap.Map(center=[48.5, -77], zoom=10)
m.split_map(
    left_layer='tifs/false_color_05_11_2023_Quebec.tif',
    right_layer='tifs/false_color_10_03_2023_Quebec.tif',
    left_label='05-11-2023',
    right_label='10-03-2023'
)
m

# %% [markdown]
# Above is what is called a 'false color' image. In this false color image, the near infrared (NIR) band replaces the red band. The NIR band is sensitive to the chlorophyll in leafy vegetation, making the false color image a useful tool for investigating vegatation change between two images. Here, red pixels are a strong indicator of vegetation cover, whereas blue and green colors pixels are more indicative of non-vegetative cover. Notice the regions which appear more red in the left (pre-fire) image and more blue-green in the second (post-fire) image. These regions have undergone vegetation loss between the two `HLS` acquisitions. Zoom in on the image to view the changes in more detail.
#
# Another way to highlight vegetation pixels is through the use of the NDVI. This is a band ratio between the NIR and red bands, which produces an image with values ranging from -1 and 1. Values nearer -1 are less likely to be vegetation, whereas values near 1 are very likely to represent vegetation. Let's have a look at the NDVI images we have produced.

# %%
m = leafmap.Map(center=[48.5, -77], zoom=10)
m.split_map(
    left_layer='tifs/ndvi_05_11_2023_Quebec.tif',
    right_layer='tifs/ndvi_10_03_2023_Quebec.tif',
    left_label='05-11-2023',
    right_label='10-03-2023'
)
m

# %% [markdown]
# NDVI values range from -1 to 1. The commonly used RdYlGn colormap (Red–Yellow–Green) helps visualize these values, where colors intuitively indicate vegetation health:
#
# | NDVI Value     | Color        | Meaning                              |
# |----------------|--------------|--------------------------------------|
# | -1.0 to -0.2   | 🔴 Red        | Water, clouds, snow, barren land     |
# | -0.2 to  0.0   | 🟠 Orange     | Rocks, bare soil, urban              |
# |  0.0 to  0.2   | 🟡 Yellow     | Sparse or stressed vegetation        |
# |  0.2 to  0.5   | 🟢 Light Green| Moderate vegetation                  |
# |  0.5 to  0.8   | 🟢 Green      | Dense, healthy vegetation            |
# |  0.8 to  1.0   | 🟢 Dark Green | Very dense, tropical vegetation      |
#
#
# In the map above, shades of green indicate areas with higher NDVI values — typically representing healthy or dense vegetation. In contrast, red, orange, and yellow tones highlight areas with low or no vegetation, such as water, built-up land, or bare ground.
#
# Use the slider to pan between the pre- and post-fire change NDVI tiles. Are vegetation losses or changes more clearly visible with this color representation?
#
# Let's now turn to look at the `DIST-ANN-HLS` product, representing the yearly summary of vegetation change for the region of interest. The next cell pans between the NDVI image we have produced and the co-located `DIST-ANN-HLS` product. While the `DIST-ANN-HLS `product is not derived from the NDVI data directly, there is a clear relationship between the vegetation decrease indicated in the NDVI and the pixels classified as 'disturbance' in the `DIST-ANN-HLS` data.

# %%
m = leafmap.Map(center=[48.5, -77], zoom=10)
m.split_map(
    left_layer='tifs/ndvi_10_03_2023_Quebec.tif',
    right_layer='tifs/veg_dist_status_Quebec.tif',
    left_label="10-03-2023 NDVI",
    right_label="2023 DIST-ANN-HLS; VEG-DIST-STATUS"
)
m

# %% [markdown]
# ## Visualize and Compute Cumulative Areas of Disturbance from the `VEG-DIST-STATUS` layer of the `OPERA DIST-ANN` product
# We will now visualize and quantitatively explore the annual summary of disturbance associated with the fire-impaced region of Quebec using the OPERA `DIST-ANN-HLS` product, and specifically the `VEG-DIST-STATUS` layer. To do so, we can use an interactive map and draw functionality provided by the open-source `leafmap` and `ipyleaflet` libraries. Execute the cell below and use the 'draw' tool to define a rectangular region over an area that appears to show disturbance.

# %%
# Make leaflet map
m = leafmap.Map(basemap=ipyleaflet.basemaps.Esri.WorldImagery,
    zoom=9,
    crs=ipyleaflet.projections.EPSG3857,
    draw_control=False)

# Add raster draw functionality
m.add_raster('tifs/veg_dist_status_Quebec.tif')
dc = ipyleaflet.DrawControl(
    polygon={},
    rectangle={"shapeOptions": {"color": "blue"}},
    circlemarker={},
    circle = {},
    polyline={}
)

# Draw an AOI on an interactive map
print('Select an Area of Interest using the tools on the left side of the map.')
dc.on_draw(handle_draw)
m.add_control(dc)
display(m)

# %% [markdown]
# Any pixel which registers as confirmed disturbance in `VEG-DIST-STATUS` layer of the `DIST-ALERT-HLS` product throughout the calendar year will be added to the `VEG-DIST-STATUS` layer of the `DIST-ANN-HLS` summary product for that year. The `VEG-DIST-STATUS` layer of the `DIST-ANN-HLS` product tracks only confirmed changes, whether the disturbance was greater or less than 50%, and whether the disturbance is `completed` or `ongoing`. Using custom functions in `dist_utils.py` we can compute cumulative areas of disturbance for each `VEG-DIST-STATUS` class to quantify the extent of disturbance throughout the 2023 calendar year.

# %%
# User-Defined Parameters
from shapely import box
ll = dc.last_draw['geometry']['coordinates'][0][0]
ur = dc.last_draw['geometry']['coordinates'][0][2]
aoi = box(ll[0], ll[1], ur[0], ur[1])
pixel_area = 30 * 30

# Create GeoDataFrame from user-specified bounding box
gdf = gpd.GeoDataFrame(index=[0], crs='epsg:4326', geometry=[aoi])

# Compute statistics within bounding box
stats = leafmap.zonal_stats(gdf, 'tifs/veg_dist_status_Quebec.tif', stats=['count'], categorical=True)[0]
del stats['count']
for i in [0,3,6,7,8,9,10]:
    if i not in stats:
        stats[i] = 0
        
affected_areas = compute_areas([stats], pixel_area, product='ann', date=None)
affected_areas

# %% [markdown]
# Above, you should see a dataframe containing rows for each `VEG-DIST-STATUS` class, their description, and the cumulative areas of vegetation disturbance in square kilometers and hectares.

# %% [markdown]
# ## Conclusion
# This notebook provides a tool for accessing and visualizing Harmonized Landsat and Sentinel-2 (`HLS`) data and the OPERA Land Surface Disturbance Annual from Harmonized Landsat and Sentinel-2 (`DIST-ANN-HLS`) product and quantifying the impact of a wildfire on vegetation change. The OPERA `DIST-ALERT-HLS` product tracks the temporal record of vegetation disturbance, wheras the `DIST-ANN-HLS` product (what we explored in this notebook) provides a summary of the disturbance that occured over the course of the calendar year. This notebook also demonstrates how the `leaflet` and `ipyleaflet` libraries may be used to create enhanced visualizations over user-specified areas. For additional use-case examples of the OPERA products, see the [OPERA Applications Github repository](https://github.com/OPERA-Cal-Val/OPERA_Applications).
